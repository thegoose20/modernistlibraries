# %%
# import helpful tools for data analysis and visualization
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# pull in the Modernist Libraries dataset
ml = pd.read_csv('ModernistLibraries20171025_UTF-8', header=0)
#View the first few rows of the dataset
ml.head()
# Out:
#    BookOwnerVIAFID     BookOwnerName   WorkID    BookID  \
# 0         97006051  Ernest Hemingway  4650949  25197870
# 1         97006051  Ernest Hemingway  4650967  25198046
# 2         97006051  Ernest Hemingway   429839  25198087
# 3         97006051  Ernest Hemingway   429839  25198220
# 4         97006051  Ernest Hemingway  7785885  25198292
#
#                                            BookTitle         BookAuthorName  \
# 0                 Sinistro and celebration: 19 poems                 A.E.T.
# 1  Tauromaquia y taurogogía: Algunos concertos bá...   R. Abarquero Durango
# 2  We pointed them North; recollections of a cowp...  Edward Charles Abbott
# 3  We pointed them north; recollections of a cowp...  Edward Charles Abbott
# 4                                     Japan unmasked   Hallett Edward Abend
#
#                                       BookPubDetails  BookPubDate  BookNotes  \
# 0                                               1956         1956        NaN
# 1                             Madrid: Torroba, 1959.         1959        NaN
# 2  Norman: University of Oklahoma Press [1955, c1...         1955        NaN
# 3          New York: Farrar & Rinehart, inc. [c1939]         1939        NaN
# 4                 New York: I. Washburn, Inc., 1941.         1941        NaN
#
#    BookCollection    InformationSource
# 0    Finca Vigia.         manual entry
# 1    Finca Vigia.         manual entry
# 2    Finca Vigia.  Library of Congress
# 3    Finca Vigia.  Library of Congress
# 4    Finca Vigia.  Library of Congress

# %%
print("Modern Libraries Columns:", list(ml.columns))

mlSize = ml.shape

# Remove extra space that appeared before certain column names ([ ... ' BookPubDate', ' BookNotes', ' BookCollection' ... ])
ml.columns = ['BookOwnerVIAFID', 'BookOwnerName', 'WorkID', 'BookID', 'BookTitle', 'BookAuthorName', 'BookPubDetails', 'BookPubDate', 'BookNotes', 'BookCollection', 'InformationSource']
print(ml.columns)

# create dictionaries of indeces associated with arrays that contain subsets of the dataset
totalRows = mlSize[0]

indeces = []
for n in range(0,totalRows):
    indeces += [n]
assert len(indeces) == ml.shape[0]

time = dict.fromkeys(indeces, '') # BookPubDate
pub = dict.fromkeys(indeces, '') # BookPubDetails
owners = dict.fromkeys(indeces, '') # BookOwnerName
authors = dict.fromkeys(indeces, '') # BookAuthorName
books = dict.fromkeys(indeces, 0) # BookID
titles = dict.fromkeys(indeces, 0) # BookTitle
for index,row in ml.iterrows():
    timeValue = str(row['BookPubDate'])
    time[index] = timeValue
    
    pubValue = str(row['BookPubDetails'])
    pub[index] = pubValue
    
    ownersValue = str(row['BookOwnerName'])
    owners[index] = ownersValue
    
    authorsValue = str(row['BookAuthorName'])
    authors[index] = authorsValue
    
    booksValue = int(row['BookID'])
    books[index] = booksValue
    
    titlesValue = str(row['BookTitle'])
    titles[index] = titlesValue


assert len(time) == totalRows, "The length of the publishing date dictionary equal the total number of rows in the dataset"
assert len(pub) == totalRows,  "The length of the publishing details dictionary equal the total number of rows in the dataset"
assert len(owners) == totalRows,  "The length of the owners dictionary equal the total number of rows in the dataset"
assert len(authors) == totalRows,  "The length of the authors dictionary equal the total number of rows in the dataset"
assert len(books) == totalRows,  "The length of the book ID dictionary equal the total number of rows in the dataset"
assert len(titles) == totalRows, "The length of the titles dictionary equal the total number of rows in the dataset"

assert time[0] == ml.iloc[0, 7], "The time dictionary has the right values from the BookPubDate column"
assert pub[200] == ml.iloc[200, 6], "The pub dictionary has the right values from the BookPubDetails column"
assert owners[20020] == ml.iloc[20020, 1], "The owners dict has the right values from BookOwnerName"
assert authors[1001] == ml.iloc[1001, 5], "The authors dict has the right values from BookAuthorName"
assert books[3] == ml.iloc[3, 3], "The books dict has the right values from BookID"
# Out:
# Modern Libraries Columns: ['BookOwnerVIAFID', 'BookOwnerName', 'WorkID', 'BookID', 'BookTitle', 'BookAuthorName', ' BookPubDetails', ' BookPubDate', ' BookNotes', ' BookCollection', 'InformationSource']
# Index(['BookOwnerVIAFID', 'BookOwnerName', 'WorkID', 'BookID', 'BookTitle',
#        'BookAuthorName', 'BookPubDetails', 'BookPubDate', 'BookNotes',
#        'BookCollection', 'InformationSource'],
#       dtype='object')

# %%
# Capitalize owner names consistently
keysToFix = []
for key in owners:
    if owners[key] is "e.e. cummings":
        keysToFix += [key]
        owners[key] = "E.E. Cummings"
    if owners[key] is "Ezra POUND":
        keysToFix += [key]
        owners[key] = "Ezra Pound"
for k in keysToFix:
    assert owners[k] != "e.e. cummings", "E.E. Cummings' name should be properly capitalized in the dataset"
    assert owners[k] != "Ezra POUND", "Ezra Pound's name should be properly capitalized in the dataset"

# %%
# Clean up dates

# Figure out the range of publication dates
pubDates = list(ml.loc[:, 'BookPubDate'])
#print(pubDates)
totalPubDates = len(pubDates)
assert totalPubDates == ml.shape[0], "There should be one BookPubDate value per row in the dataframe"

numeric = []
nonNumeric = []
for date in pubDates:
    date = str(date)
    if str.isdigit(date):
        numeric += [date]
    else:
        nonNumeric += [date]

#for x in numeric:
    #assert len(x) == 4, "All numeric dates should have 4 characters"
    #assert str.isdigit(date), "All numeric dates' characters should be digits"
#assert (len(numeric) + len(nonNumeric)) == len(pubDates), "All dates in the dataset should appear in either numeric or nonNumeric (not both"

print("nonNumeric Dates:", len(nonNumeric))
print("numeric Dates:", len(numeric))

# find book with invalid numeric date
invalidNumericDate = []
for d in numeric:
    if len(d) != 4:
        invalidNumericDate += [d]
print("Invalid Numeric Dates:", invalidNumericDate)
invalidDateIndeces = []
for d in invalidNumericDate:
    invalidDateIndeces += [pubDates.index(str(d))]
#print(invalidDateIndeces)

import re

# investigate non-numeric BookPubDate values
#uniqueNonNumeric = np.unique(nonNumeric)
#for value in uniqueNonNumeric:
    #print(i, ":", value)
    #i += 1
    #print(value)

# define lists to create for new StartYear and EndYear columns
StartYear = []
EndYear = []
for d in pubDates:
    d = str(d)
    d = d.lower()
    d = d.strip('abcdefghijklmnopqrstuv')
    d = d.strip(',')
    d = d.strip('[')
    d = d.strip('?]')
    d = d.strip(']')

    # fix invalid values that are all numeric
    if d == '188' or d == '18888':
        StartYear += [int(1888)]
        EndYear += [int(1888)]
    
    else:
    
        # get all four-digit years into StartYear and EndYear
        y0 = re.search('[1-9]{1}[0-9]{3}$', d)  # example: 1926
        if y0 != None:
            add0 = y0.group(0)
            StartYear += [int(add0)]
            EndYear += [int(add0)]
            if len(add0) != 4:
                print(add0)
    
        # divide ranges of years into StartYear and EndYear
        elif len(d) > 3:
            y1 = re.search('[1-9]{1}[0-9]{3}-[0-9]{1}$', d)  # example: 1990-1
            if y1 != None:
                add1 = y1.group(0)
                s1 = (add1[0]+add1[1]+add1[2]+add1[3])
                e1 = (add1[0]+add1[1]+add1[2]+add1[5])
                StartYear += [int( s1 )]
                EndYear += [int( e1 )]
                if len(s1) != 4:
                    print(s1)
                    print("Add1:", add1)
                if len(e1) != 4:
                    print(e1)
                    print("Add1:", add1)
            else:
                y2 = re.search('[1-9]{1}[0-9]{3}-[0-9]{2}$', d)  # example: 1940-45
                if y2 != None:
                    add2 = y2.group(0)
                    s2 = (add2[0]+add2[1]+add2[2]+add2[3])
                    e2 = (add2[0]+add2[1]+add2[5]+add2[6])
                    StartYear += [int( s2 )]
                    EndYear += [int( e2 )]
                    if len(s2) != 4:
                        print(s2)
                        print("Add2:", add2)
                    if len(e2) != 4:
                        print(e2)
                        print("Add2:", add2)
                else:
                    y3 = re.search('([1-9]{1}[0-9]{3})(-|\/)([1-9]{1}[0-9]{3})', d)  # example: 1930-1940
                    if y3 != None:
                        add3 = y3.group(0)
                        s3 = (add3[0]+add3[1]+add3[2]+add3[3])
                        e3 = (add3[5]+add3[6]+add3[7]+add3[8])
                        StartYear += [int( s3 )]
                        EndYear += [int( e3 )]
                        if len(s3) != 4:
                            print(s3)
                            print("Add3:", add3)
                        if len(e3) != 4:
                            print(e3)
                            print("Add3:", add3)
                    else:

        # create ranges for incomplete years
                        y4 = re.search('\d{2}-{2}$', d)  # example: 19--
                        if y4 != None:
                            add4 = y4.group(0)
                            s4 = (add4[0]+add4[1]+'0'+'0')
                            e4 = (add4[0]+add4[1]+'9'+'9')
                            StartYear += [int( s4 )]
                            EndYear += [int( e4 )]
                            if len(s4) != 4:
                                print(s4)
                                print("Add4:", add4)
                            if len(e4) != 4:
                                print(e4)
                                print("Add4:", add4)
                        else:
                            y5 = re.search('\d{3}-{1}$', d)  # example: 193-
                            if y5 != None:
                                add5 = y5.group(0)
                                s5 = (add5[0]+add5[1]+add5[2]+'0')
                                e5 = (add5[0]+add5[1]+add5[2]+'9')
                                StartYear += [int( s5 )]
                                EndYear += [int( e5 )]
                                if len(s5) != 4:
                                    print(s5)
                                    print("Add5:", add5)
                                if len(e5) != 4:
                                    print(e5)
                                    print("Add5:", add5)

        # make the rest 9999 (will need to compare to pub details or investigate manually)
                            else:
                                StartYear += [int(9999)]
                                EndYear += [int(9999)]
        else:
            StartYear += [int(9999)]
            EndYear += [int(9999)]

for pubDate in StartYear:
    assert type(pubDate) == int, "All start dates should be ints"
    assert len(str(pubDate)) == 4, "All start dates should be four digits long"
for pubDate in EndYear:
    assert type(pubDate) == int, "All end dates should be ints"
    assert len(str(pubDate)) == 4, "All end dates should be four digits long"
assert len(StartYear) == mlSize[0], "There should be one StartYear value for every row in the dataset"
assert len(EndYear) == mlSize[0], "There should be one EndYear value for every row in the dataset"

startToInvestigate = 0
endToInvestigate = 0
validStartYears = []
validEndYears = []
for pubDate in StartYear:
    if pubDate == 0 or pubDate > 2017:
        startToInvestigate += 1
    else:
        validStartYears += [pubDate]

for pubDate in EndYear:
    if pubDate == 0 or pubDate > 2017:
        endToInvestigate += 1
    else:
        validEndYears += [pubDate]

yearRanges = []
singleYear = []
toInvestigate = 0
for i in range(0, (mlSize[0])):
    if (StartYear[i] == 9999) or (EndYear[i] == 9999):
        toInvestigate += 1
    elif StartYear[i] < EndYear[i]:
        yearRanges += [EndYear[i] - StartYear[i]]
    elif StartYear[i] == EndYear[i]:
        singleYear += [StartYear[i]]
    else:
        toInvestigate += 1
print("To Investigate:", toInvestigate)  #I'll drop the rows with these 2353 invalid/unknown dates
print(StartYear[4])
# Out:
# nonNumeric Dates: 2567
# numeric Dates: 20784
# Invalid Numeric Dates: ['188', '18888']
# To Investigate: 2353
# 1941

# %%
# Ernest Hemingway's Library
EHBooks = 0
EHDates = 0
for key in owners:
    x = (owners[key]).lower()
    if "hemingway" in x:
        EHBooks += 1
        pubdate = StartYear[key]
        if (pubdate > 1939) and (pubdate < 1961):
            EHDates += 1
print(EHBooks)
print(EHDates)
print(EHDates/EHBooks)
# Out:
# 7408
# 4487
# 0.6056965442764579

# %%
import networkx as nx

# %% [markdown]
# **Using NetworkX**
#
# *from https://networkx.github.io/documentation/networkx-1.10/reference/introduction.html*
#
# * Edges should be directed to indicate whether someone owns a book or whether someone's book was owned by one of the libraries in the dataset
# * Multiple edges should be allowed between pairs of nodes, because one owner can have books by many authors and one author can appear in many owners' libraries
# * Edge data could include time (publishing dates), location (publishing locations), and count (number of books) however this data is not necessary to understand the relationships between the nodes because each node represents the same relationship: book ownership
# * Node data should be hashable, so each person should have a unique name and an attribute that categorizes them as a book author, book owner or both in the Modernist Libraries dataset
#
# The appropriate graph class to use for the Modernist Libraries dataset is thus MultiDiGraph.  Graphs can be created in one of three ways:
#
# * Graph generators – standard algorithms to create network topologies
# * Importing data from pre-existing (usually file) sources
# * Adding edges and nodes explicitly
#
# As the pre-existing file sources in the tutorial for importing data does not include CSV files, I will add edges and nodes explicitly from the Modernist Libraries dataset to create a MultiDiGraph network.

# %%
# Make network nodes for book authors and owners
bookOwnersList = list(ml['BookOwnerName'].unique())
bookAuthorsList = list(ml['BookAuthorName'].unique())
#print("Book Owners:", bookOwnersList)
#print("Book Authors:", bookAuthorsList)
print("Total Book Authors Count:", len(bookAuthorsList))

# Capitalize owner names consistently
bookOwnersList[5] = "E.E. Cummings"
for i in owners:
    if owners[i] is "e.e. cummings":
        owners[i] == "E.E. Cummings"

print("Book Owners:", bookOwnersList)
ppl = bookAuthorsList
for owner in bookOwnersList:
    if owner not in bookAuthorsList:
        ppl += [owner]
print(len(ppl))
indeces = []
for n in range(0,len(ppl)):
    indeces += [n]
assert len(indeces) == len(ppl), "There should be one index per person in the Modernist Libraries dataset"

pplDict = dict.fromkeys(indeces, '')
for i in indeces:
    pplDict[i] = str(ppl[i])
assert len(pplDict) == len(ppl), "There should be one key-value pair per person in the Modernist Libraries dataset"
print(pplDict[1])
print(pplDict[12000])
# Out:
# Total Book Authors Count: 12729
# Book Owners: ['Ernest Hemingway', 'James Joyce', 'W.H. Auden', 'Ezra Pound', 'F. Scott Fitzgerald', 'E.E. Cummings', 'W.B. Yeats', "Flannery O'Connor", 'Virginia Woolf', 'Gertrude Stein', 'Edith Sitwell', 'Edna St. Vincent Millay', 'Langston Hughes']
# 12733
# R. Abarquero Durango
# St_phane Mallarm_

# %% [markdown]
# There will be some node name cleanup to do! (see last print line above)
#
#
# To create the Modernist Libraries network of relationships between book owners and book authors, I'll:
# 1. Initialize a graph that allows for directionality to distinguish owner from owned, and allows for multiple relationships (edges) between two nodes (because, for example, owners may own multiple books by a single author)
# 2. Create nodes for the owners and authors, with attributes indicating whether the person was an owner or author
# 3. Create edges from owners to authors, with attributes for the title, ID, publishing date and publishing location of the owned book

# %%
# Initialize another empty Modernist Libraries network
libs = nx.MultiDiGraph()

# Each node should return {i : {name : '', owner : T/F, author : T/F}}
ownStatus = dict.fromkeys(indeces, 0)
authStatus = dict.fromkeys(indeces, 0)
for i in indeces:
    person = pplDict[i]
    if person in bookOwnersList:
        ownStatus[i] = 1            # if person is book owner, set to 1 (true)
    if person in bookAuthorsList:
        authStatus[i] = 1           # if person is book author, set to 1 (true)
assert len(ownStatus) == len(pplDict), "Ownership dictionary should have one entry per person"
assert len(authStatus) == len(pplDict), "Authorship dictionary should have one entry per person"

for i in indeces:
    person = pplDict[i]
    libs.add_node(person, {'owner' : ownStatus[i], 'author' : authStatus[i]})

print(libs.node["Edward Charles Abbott"])
print("Length:", len(libs))
assert(len(libs) == len(ppl)), "There should be one node per person in the Modernist Libraries network"
# Out:
# {'owner': 0, 'author': 1}
# Length: 12733

# %%
# Add edges: MultiDiGraph.add_edge(u, v[, key, attr_dict])
# Each edge should have attributes for book title, ID, time (publication date) and location (publishing city)
for i in range(0,totalRows):
    ownerNode = owners[i]
    authorNode = authors[i]
    edgeAttrs = { 'titles' : titles[i], 'book ID' : books[i], 'publication date' : time[i], 'publication city' : pub[i] }
    libs.add_edge(ownerNode, authorNode, object=edgeAttrs)

print("Edges:", libs.number_of_edges())
print("Nodes:", libs.number_of_nodes())
# Out:
# Edges: 23351
# Nodes: 12734

# %% [markdown]
# Now that the network is built, I can calculate the shortest path from one person to another:

# %%
sp = dict(nx.all_pairs_shortest_path(libs))
sp["Ernest Hemingway"]
# Out:
# {'Ernest Hemingway': ['Ernest Hemingway'],
#  'A.E.T.': ['Ernest Hemingway', 'A.E.T.'],
#  'R. Abarquero Durango': ['Ernest Hemingway', 'R. Abarquero Durango'],
#  'Edward Charles Abbott': ['Ernest Hemingway', 'Edward Charles Abbott'],
#  'Hallett Edward Abend': ['Ernest Hemingway', 'Hallett Edward Abend'],
#  'Edmundo González Acebal': ['Ernest Hemingway', 'Edmundo González Acebal'],
#  'Dean Acheson': ['Ernest Hemingway', 'Dean Acheson'],
#  'Julián Acuña': ['Ernest Hemingway', 'Julián Acuña'],
#  'George Adam': ['Ernest Hemingway', 'George Adam'],
#  ' Louis Adamic': ['Ernest Hemingway', ' Louis Adamic'],
#  'Charlotte Adams': ['Ernest Hemingway', 'Charlotte Adams'],
#  'Cleve F. Adams': ['Ernest Hemingway', 'Cleve F. Adams'],
#  'Franklin P. Adams': ['Ernest Hemingway', 'Franklin P. Adams'],
#  'Henry Adams': ['Ernest Hemingway', 'Henry Adams'],
#  'James Donald Adams': ['Ernest Hemingway', 'James Donald Adams'],
#  'James Truslow Adams': ['Ernest Hemingway', 'James Truslow Adams'],
#  'Nicholson B. Adams': ['Ernest Hemingway', 'Nicholson B. Adams'],
#  'Ramon F. Adams': ['Ernest Hemingway', 'Ramon F. Adams'],
#  'Richard P. Adams': ['Ernest Hemingway', 'Richard P. Adams'],
#  'Samuel Hopkins Adams': ['Ernest Hemingway', 'Samuel Hopkins Adams'],
#  'Charles Addams': ['Ernest Hemingway', 'Charles Addams'],
#  'Polly Adler': ['Ernest Hemingway', 'Polly Adler'],
#  'Adler Planetarium and Astronomical Museum': ['Ernest Hemingway',
#   'Adler Planetarium and Astronomical Museum'],
#  'Frederick George Aflalo': ['Ernest Hemingway', 'Frederick George Aflalo'],
#  'Herbert Agar': ['Ernest Hemingway', 'Herbert Agar'],
#  'James Agee': ['Ernest Hemingway', 'James Agee'],
#  'Mary Allerton': ['Ernest Hemingway', 'Mary Allerton'],
#  'Rewi Alley': ['Ernest Hemingway', 'Rewi Alley'],
#  'Margery Allingham': ['Ernest Hemingway', 'Margery Allingham'],
#  '[N.auth]': ['Ernest Hemingway', '[N.auth]'],
#  'Luis Alayza Paz Soldán': ['Ernest Hemingway', 'Luis Alayza Paz Soldán'],
#  'Miriam Allott (ed.)': ['Ernest Hemingway', 'Miriam Allott (ed.)'],
#  'Antoine Albalat': ['Ernest Hemingway', 'Antoine Albalat'],
#  'Rubert Royce Allyn': ['Ernest Hemingway', 'Rubert Royce Allyn'],
#  'E. M. Almedingen': ['Ernest Hemingway', 'E. M. Almedingen'],
#  'Hollis Alpert': ['Ernest Hemingway', 'Hollis Alpert'],
#  'Stewart Alsop': ['Ernest Hemingway', 'Stewart Alsop'],
#  'Joseph Alexander Altsheler': ['Ernest Hemingway',
#   'Joseph Alexander Altsheler'],
#  'Basilio Alvarez': ['Ernest Hemingway', 'Basilio Alvarez'],
#  'Marcelino [Marcelo] Alvarez': ['Ernest Hemingway',
#   'Marcelino [Marcelo] Alvarez'],
#  'Julio Alvarez del Vayo': ['Ernest Hemingway', 'Julio Alvarez del Vayo'],
#  'Armando Alvarez Pedroso': ['Ernest Hemingway', 'Armando Alvarez Pedroso'],
#  'George Sumner Albee': ['Ernest Hemingway', 'George Sumner Albee'],
#  'José Amador de Los Rios': ['Ernest Hemingway', 'José Amador de Los Rios'],
#  'Arturo Alberni': ['Ernest Hemingway', 'Arturo Alberni'],
#  'Martha Albrand': ['Ernest Hemingway', 'Martha Albrand'],
#  'Album Cubane': ['Ernest Hemingway', 'Album Cubane'],
#  'John T. Amber (ed.)': ['Ernest Hemingway', 'John T. Amber (ed.)'],
#  'George Amberg': ['Ernest Hemingway', 'George Amberg'],
#  'Eric Ambler': ['Ernest Hemingway', 'Eric Ambler'],
#  'Federico M. Alcázar': ['Ernest Hemingway', 'Federico M. Alcázar'],
#  'Alcoholics Anonymous': ['Ernest Hemingway', 'Alcoholics Anonymous'],
#  'Louisa May Alcott': ['Ernest Hemingway', 'Louisa May Alcott'],
#  'Richard Aldington': ['Ernest Hemingway', 'Richard Aldington'],
#  'Francis Ambrière': ['Ernest Hemingway', 'Francis Ambrière'],
#  'Léon Ameline': ['Ernest Hemingway', 'Léon Ameline'],
#  'Waldo Frank (ed.)': ['Ernest Hemingway', 'Waldo Frank (ed.)'],
#  'Mildred Aldrich': ['Ernest Hemingway', 'Mildred Aldrich'],
#  'James Aldridge': ['Ernest Hemingway', 'James Aldridge'],
#  'Ciro Alegría': ['Ernest Hemingway', 'Ciro Alegría'],
#  'American Automobile Association': ['Ernest Hemingway',
#   'American Automobile Association'],
#  'James Waddell Alexander': ['Ernest Hemingway', 'James Waddell Alexander'],
#  'Sidney Alexander': ['Ernest Hemingway', 'Sidney Alexander'],
#  'Wilfrid Backhouse Alexander': ['Ernest Hemingway',
#   'Wilfrid Backhouse Alexander'],
#  'Horatio Alger': ['Ernest Hemingway', 'Horatio Alger'],
#  'Brooks Van Wyck': ['Ernest Hemingway', 'Brooks Van Wyck'],
#  'Nelson Algren': ['Ernest Hemingway', 'Nelson Algren'],
#  'American Kennel Club': ['Ernest Hemingway', 'American Kennel Club'],
#  'Ted Allan': ['Ernest Hemingway', 'Ted Allan'],
#  'American Museum of Natural History. New York City.': ['Ernest Hemingway',
#   'American Museum of Natural History. New York City.'],
#  'Ethan Allen': ['Ernest Hemingway', 'Ethan Allen'],
#  'Frederick Lewis Allen': ['Ernest Hemingway', 'Frederick Lewis Allen'],
#  'Henry Allen': ['Ernest Hemingway', 'Henry Allen'],
#  'Herbert Warner Allen': ['Ernest Hemingway', 'Herbert Warner Allen'],
#  'Hervey Allen': ['Ernest Hemingway', 'Hervey Allen'],
#  'Jerry Allen': ['Ernest Hemingway', 'Jerry Allen'],
#  'Robert S. Allen': ['Ernest Hemingway', 'Robert S. Allen'],
#  'Robert Sharon Allen (ed.)': ['Ernest Hemingway',
#   'Robert Sharon Allen (ed.)'],
#  'Walter Ernest Allen': ['Ernest Hemingway', 'Walter Ernest Allen'],
#  'Francesca Raimonde La Monte': ['Ernest Hemingway',
#   'Francesca Raimonde La Monte'],
#  'Cleveland Amory': ['Ernest Hemingway', 'Cleveland Amory'],
#  'Karl Baedeker (Firm)': ['Ernest Hemingway', 'Karl Baedeker (Firm)'],
#  'Alfred Andersch': ['Ernest Hemingway', 'Alfred Andersch'],
#  'Karl Baedeker': ['Ernest Hemingway', 'Karl Baedeker'],
#  'Henry Philip Bernard Baerlein': ['Ernest Hemingway',
#   'Henry Philip Bernard Baerlein'],
#  'Hans Christian Andersen': ['Ernest Hemingway', 'Hans Christian Andersen'],
#  'Ventura Bagüés': ['Ernest Hemingway', 'Ventura Bagüés'],
#  'M. Bielmann': ['Ernest Hemingway', 'M. Bielmann'],
#  'Jerome Bahr': ['Ernest Hemingway', 'Jerome Bahr'],
#  'Ambrose Bierce': ['Ernest Hemingway', 'Ambrose Bierce'],
#  'Francis Hill Bigelow': ['Ernest Hemingway', 'Francis Hill Bigelow'],
#  'Henry Christopher Bailey': ['Ernest Hemingway', 'Henry Christopher Bailey'],
#  'Earl Derr Biggers': ['Ernest Hemingway', 'Earl Derr Biggers'],
#  'Eileen Bigland': ['Ernest Hemingway', 'Eileen Bigland'],
#  'Francesco Bigliazzi': ['Ernest Hemingway', 'Francesco Bigliazzi'],
#  'Fernand Biguet': ['Ernest Hemingway', 'Fernand Biguet'],
#  'Liberty Hyde Bailey': ['Ernest Hemingway', 'Liberty Hyde Bailey'],
#  'Ray Allen Billington': ['Ernest Hemingway', 'Ray Allen Billington'],
#  'André Billy': ['Ernest Hemingway', 'André Billy'],
#  'John Bainbridge': ['Ernest Hemingway', 'John Bainbridge'],
#  'John Edwin Bakeless': ['Ernest Hemingway', 'John Edwin Bakeless'],
#  'Carlos Heard Baker': ['Ernest Hemingway', 'Carlos Heard Baker'],
#  'James K. Binder': ['Ernest Hemingway', 'James K. Binder'],
#  'Archie Binns': ['Ernest Hemingway', 'Archie Binns'],
#  'André Birabeau': ['Ernest Hemingway', 'André Birabeau'],
#  'Charles Henry Baker': ['Ernest Hemingway', 'Charles Henry Baker'],
#  'D. Percival Lea Birch': ['Ernest Hemingway', 'D. Percival Lea Birch'],
#  'Baron Christopher Bromhead Birdwood': ['Ernest Hemingway',
#   'Baron Christopher Bromhead Birdwood'],
#  'Clyde Baker': ['Ernest Hemingway', 'Clyde Baker'],
#  'Dorothy (Dodds) Baker': ['Ernest Hemingway', 'Dorothy (Dodds) Baker'],
#  'Edward Mayer Baker': ['Ernest Hemingway', 'Edward Mayer Baker'],
#  'George Baker': ['Ernest Hemingway', 'George Baker'],
#  'Ray Stannard Baker': ['Ernest Hemingway', 'Ray Stannard Baker'],
#  'Samuel White Baker': ['Ernest Hemingway', 'Samuel White Baker'],
#  'Sherman Baker': ['Ernest Hemingway', 'Sherman Baker'],
#  'Charles Montague Bakewell': ['Ernest Hemingway',
#   'Charles Montague Bakewell'],
#  'Glenn Balch': ['Ernest Hemingway', 'Glenn Balch'],
#  'William Balck': ['Ernest Hemingway', 'William Balck'],
#  'Hanson Weightman Baldwin': ['Ernest Hemingway', 'Hanson Weightman Baldwin'],
#  'William Charles Baldwin': ['Ernest Hemingway', 'William Charles Baldwin'],
#  'Doris Bell Ball': ['Ernest Hemingway', 'Doris Bell Ball'],
#  'James Ballard': ['Ernest Hemingway', 'James Ballard'],
#  'Maturin Murray Ballou': ['Ernest Hemingway', 'Maturin Murray Ballou'],
#  'Consuelo Vanderbilt Balsan': ['Ernest Hemingway',
#   'Consuelo Vanderbilt Balsan'],
#  'Honoré de Balzac': ['Ernest Hemingway', 'Honoré de Balzac'],
#  'Carel Birkby': ['Ernest Hemingway', 'Carel Birkby'],
#  'Hoffman Birney': ['Ernest Hemingway', 'Hoffman Birney'],
#  'Lajos Biró': ['Ernest Hemingway', 'Lajos Biró'],
#  'Louis Edward Bisch': ['Ernest Hemingway', 'Louis Edward Bisch'],
#  'Elizabeth Bishop': ['Ernest Hemingway', 'Elizabeth Bishop'],
#  'Herman Bishop': ['Ernest Hemingway', 'Herman Bishop'],
#  'Jim Bishop': ['Ernest Hemingway', 'Jim Bishop'],
#  'John Peale Bishop': ['Ernest Hemingway', 'John Peale Bishop'],
#  'Richard Pike Bissell': ['Ernest Hemingway', 'Richard Pike Bissell'],
#  'Sir James Gordon Partridge Bisset': ['Ernest Hemingway',
#   'Sir James Gordon Partridge Bisset'],
#  'Ruby Aurora Black': ['Ernest Hemingway', 'Ruby Aurora Black'],
#  'Susan Leigh Blackford': ['Ernest Hemingway', 'Susan Leigh Blackford'],
#  'W. W. Blackford': ['Ernest Hemingway', 'W. W. Blackford'],
#  'Richard Doddridge Blackmore': ['Ernest Hemingway',
#   'Richard Doddridge Blackmore'],
#  'E.T. Ellis': ['Ernest Hemingway', 'E.T. Ellis'],
#  'William Garden Blaikie': ['Ernest Hemingway', 'William Garden Blaikie'],
#  'Forrester Blake': ['Ernest Hemingway', 'Forrester Blake'],
#  'William J. Blake': ['Ernest Hemingway', 'William J. Blake'],
#  'Griffing Bancroft': ['Ernest Hemingway', 'Griffing Bancroft'],
#  'Lesley Blanch': ['Ernest Hemingway', 'Lesley Blanch'],
#  'Gian Andrea Bandini': ['Ernest Hemingway', 'Gian Andrea Bandini'],
#  'Ralph Bandini': ['Ernest Hemingway', 'Ralph Bandini'],
#  'Désiré Blanchet': ['Ernest Hemingway', 'Désiré Blanchet'],
#  'Michael Blankfort': ['Ernest Hemingway', 'Michael Blankfort'],
#  'Paul Blanshard': ['Ernest Hemingway', 'Paul Blanshard'],
#  'Vicente Blasco Ibáñez': ['Ernest Hemingway', 'Vicente Blasco Ibáñez'],
#  'Tallulah Bankhead': ['Ernest Hemingway', 'Tallulah Bankhead'],
#  'Vincente Blasco Ibáñez': ['Ernest Hemingway', 'Vincente Blasco Ibáñez'],
#  'Pierre Barbellion': ['Ernest Hemingway', 'Pierre Barbellion'],
#  "Jules Amédée Barbey d'Aurevilly": ['Ernest Hemingway',
#   "Jules Amédée Barbey d'Aurevilly"],
#  'Thomas Barbour': ['Ernest Hemingway', 'Thomas Barbour'],
#  'Ike Blasingame': ['Ernest Hemingway', 'Ike Blasingame'],
#  'Henri Barbusse': ['Ernest Hemingway', 'Henri Barbusse'],
#  'Maurice Bardèche': ['Ernest Hemingway', 'Maurice Bardèche'],
#  'F. Bleu': ['Ernest Hemingway', 'F. Bleu'],
#  'Pierre Bardel': ['Ernest Hemingway', 'Pierre Bardel'],
#  'Karen Blixen [Isak Dinesen]': ['Ernest Hemingway',
#   'Karen Blixen [Isak Dinesen]'],
#  'Arturo Barea': ['Ernest Hemingway', 'Arturo Barea'],
#  'Piero Bargellini': ['Ernest Hemingway', 'Piero Bargellini'],
#  'Maurice Baring': ['Ernest Hemingway', 'Maurice Baring'],
#  'Eugenio Barisoni': ['Ernest Hemingway', 'Eugenio Barisoni'],
#  'A. L. Barker': ['Ernest Hemingway', 'A. L. Barker'],
#  'James Barlow': ['Ernest Hemingway', 'James Barlow'],
#  'Baron Bror von Blixen-Finecke': ['Ernest Hemingway',
#   'Baron Bror von Blixen-Finecke'],
#  'Alexander Barmine': ['Ernest Hemingway', 'Alexander Barmine'],
#  'Harry Barnard': ['Ernest Hemingway', 'Harry Barnard'],
#  'Lawrence G. Blochman': ['Ernest Hemingway', 'Lawrence G. Blochman'],
#  'Jean Bloch-Michel': ['Ernest Hemingway', 'Jean Bloch-Michel'],
#  'Georges Blond': ['Ernest Hemingway', 'Georges Blond'],
#  'Murray Teigh Bloom': ['Ernest Hemingway', 'Murray Teigh Bloom'],
#  'Keppel Harcourt Barnard': ['Ernest Hemingway', 'Keppel Harcourt Barnard'],
#  'Paul and Millicent Bloomfield (eds.)': ['Ernest Hemingway',
#   'Paul and Millicent Bloomfield (eds.)'],
#  'Albert Coombs Barnes': ['Ernest Hemingway', 'Albert Coombs Barnes'],
#  'Djuna Barnes': ['Ernest Hemingway', 'Djuna Barnes'],
#  'Eric Wollencott Barnes': ['Ernest Hemingway', 'Eric Wollencott Barnes'],
#  'A. Coleman Blum': ['Ernest Hemingway', 'A. Coleman Blum'],
#  'Margaret Ayer Barnes': ['Ernest Hemingway', 'Margaret Ayer Barnes'],
#  'David Irving Blumenstock': ['Ernest Hemingway', 'David Irving Blumenstock'],
#  'Edmund Charles Blunden': ['Ernest Hemingway', 'Edmund Charles Blunden'],
#  'Godfrey Blunden': ['Ernest Hemingway', 'Godfrey Blunden'],
#  'David Enderby Blunt': ['Ernest Hemingway', 'David Enderby Blunt'],
#  'Fernando Boada': ['Ernest Hemingway', 'Fernando Boada'],
#  'Angelo del Boca': ['Ernest Hemingway', 'Angelo del Boca'],
#  'Giovanni Boccaccio': ['Ernest Hemingway', 'Giovanni Boccaccio'],
#  'Maxwell Bodenheim': ['Ernest Hemingway', 'Maxwell Bodenheim'],
#  'Thomas Bodkin': ['Ernest Hemingway', 'Thomas Bodkin'],
#  'Pio Baroja y Nessi': ['Ernest Hemingway', 'Pio Baroja y Nessi'],
#  'Frederick Bodmer': ['Ernest Hemingway', 'Frederick Bodmer'],
#  'Albert Boekholt': ['Ernest Hemingway', 'Albert Boekholt'],
#  'Boethius': ['Ernest Hemingway', 'Boethius'],
#  'Ethel Boileau': ['Ernest Hemingway', 'Ethel Boileau'],
#  'L. de Boisset': ['Ernest Hemingway', 'L. de Boisset'],
#  'Paul Darcy Boles': ['Ernest Hemingway', 'Paul Darcy Boles'],
#  'Richard Boleslavsky': ['Ernest Hemingway', 'Richard Boleslavsky'],
#  'Stanley Wade Baron': ['Ernest Hemingway', 'Stanley Wade Baron'],
#  'Alfred Hamilton Barr': ['Ernest Hemingway', 'Alfred Hamilton Barr'],
#  'James Barr': ['Ernest Hemingway', 'James Barr'],
#  'William Edmund Barrett': ['Ernest Hemingway', 'William Edmund Barrett'],
#  'Joseph Michaël Thomas Barretto de Souza': ['Ernest Hemingway',
#   'Joseph Michaël Thomas Barretto de Souza'],
#  'Luis Bollain': ['Ernest Hemingway', 'Luis Bollain'],
#  'Eduardo Barriobero y Herrán': ['Ernest Hemingway',
#   'Eduardo Barriobero y Herrán'],
#  'Luis Bollaín': ['Ernest Hemingway', 'Luis Bollaín'],
#  'Harlan Harland Barrows': ['Ernest Hemingway', 'Harlan Harland Barrows'],
#  'Nathaniel A. Barrows': ['Ernest Hemingway', 'Nathaniel A. Barrows'],
#  'Philip Barry': ['Ernest Hemingway', 'Philip Barry'],
#  'Diana Barrymore': ['Ernest Hemingway', 'Diana Barrymore'],
#  'Alain Bombard': ['Ernest Hemingway', 'Alain Bombard'],
#  'A. Bonazzi': ['Ernest Hemingway', 'A. Bonazzi'],
#  'Charles Boner': ['Ernest Hemingway', 'Charles Boner'],
#  'Jean Bartholoni': ['Ernest Hemingway', 'Jean Bartholoni'],
#  'John Bartlett': ['Ernest Hemingway', 'John Bartlett'],
#  'Vernon Bartlett': ['Ernest Hemingway', 'Vernon Bartlett'],
#  'Donald Richmond Barton': ['Ernest Hemingway', 'Donald Richmond Barton'],
#  'Jacques Barzun': ['Ernest Hemingway', 'Jacques Barzun'],
#  'Pedro de Basaldúa': ['Ernest Hemingway', 'Pedro de Basaldúa'],
#  'William Russell Bascom': ['Ernest Hemingway', 'William Russell Bascom'],
#  'Hamilton Basso': ['Ernest Hemingway', 'Hamilton Basso'],
#  'Henry Walter Bates': ['Ernest Hemingway', 'Henry Walter Bates'],
#  'Mary Greene Bonesteel': ['Ernest Hemingway', 'Mary Greene Bonesteel'],
#  'Pierre Bonnard': ['Ernest Hemingway', 'Pierre Bonnard'],
#  'Paul Hyde Bonner': ['Ernest Hemingway', 'Paul Hyde Bonner'],
#  'Stephen Bonsal': ['Ernest Hemingway', 'Stephen Bonsal'],
#  'National Geographic Society': ['Ernest Hemingway',
#   'National Geographic Society'],
#  'Charles Gordon Booth': ['Ernest Hemingway', 'Charles Gordon Booth'],
#  'Tancred Borenius': ['Ernest Hemingway', 'Tancred Borenius'],
#  'Giuseppe Antonio Borgese': ['Ernest Hemingway', 'Giuseppe Antonio Borgese'],
#  'Valerio Borghese Jr.': ['Ernest Hemingway', 'Valerio Borghese Jr.'],
#  'George Henry Borrow': ['Ernest Hemingway', 'George Henry Borrow'],
#  'Francesco Borsetta': ['Ernest Hemingway', 'Francesco Borsetta'],
#  'Henry Borsook': ['Ernest Hemingway', 'Henry Borsook'],
#  'Lauro de Bosis': ['Ernest Hemingway', 'Lauro de Bosis'],
#  'Alain Bosquet (ed.)': ['Ernest Hemingway', 'Alain Bosquet (ed.)'],
#  'Charles K. Boston': ['Ernest Hemingway', 'Charles K. Boston'],
#  'James Boswell': ['Ernest Hemingway', 'James Boswell'],
#  'Herbert Ernest Bates': ['Ernest Hemingway', 'Herbert Ernest Bates'],
#  'Marston Bates': ['Ernest Hemingway', 'Marston Bates'],
#  'Ralph Bates': ['Ernest Hemingway', 'Ralph Bates'],
#  'William Horatio Bates': ['Ernest Hemingway', 'William Horatio Bates'],
#  'A.H. Batten Pooll': ['Ernest Hemingway', 'A.H. Batten Pooll'],
#  'Charles Baudelaire': ['Ernest Hemingway', 'Charles Baudelaire'],
#  'Gérard Bauër': ['Ernest Hemingway', 'Gérard Bauër'],
#  'James E. Baum': ['Ernest Hemingway', 'James E. Baum'],
#  'Robert Newton Bavier': ['Ernest Hemingway', 'Robert Newton Bavier'],
#  'James Phinney Baxter': ['Ernest Hemingway', 'James Phinney Baxter'],
#  'Walter Baxter': ['Ernest Hemingway', 'Walter Baxter'],
#  'Emile Bayard': ['Ernest Hemingway', 'Emile Bayard'],
#  'Herbert Bayer': ['Ernest Hemingway', 'Herbert Bayer'],
#  'Leo G. Bayer': ['Ernest Hemingway', 'Leo G. Bayer'],
#  'Dorothy Julia Baynes': ['Ernest Hemingway', 'Dorothy Julia Baynes'],
#  'Léon Bazalgette': ['Ernest Hemingway', 'Léon Bazalgette'],
#  'Edward Latimer Beach': ['Ernest Hemingway', 'Edward Latimer Beach'],
#  'Joseph Warren Beach': ['Ernest Hemingway', 'Joseph Warren Beach'],
#  'Sylvia Beach': ['Ernest Hemingway', 'Sylvia Beach'],
#  'Peter S. Beagle': ['Ernest Hemingway', 'Peter S. Beagle'],
#  'Carleton Beals': ['Ernest Hemingway', 'Carleton Beals'],
#  'Charles Edwin Woodrow Bean': ['Ernest Hemingway',
#   'Charles Edwin Woodrow Bean'],
#  'Charles Austin Beard': ['Ernest Hemingway', 'Charles Austin Beard'],
#  'Allan R. Bosworth': ['Ernest Hemingway', 'Allan R. Bosworth'],
#  'Bernard Botein': ['Ernest Hemingway', 'Bernard Botein'],
#  'Carl Huntington Bottume': ['Ernest Hemingway', 'Carl Huntington Bottume'],
#  'Robert Boucard': ['Ernest Hemingway', 'Robert Boucard'],
#  'Pierre Bouchardon': ['Ernest Hemingway', 'Pierre Bouchardon'],
#  'Xavier Marcel Boulestin': ['Ernest Hemingway', 'Xavier Marcel Boulestin'],
#  'Pierre Boulle': ['Ernest Hemingway', 'Pierre Boulle'],
#  'Vance Bourjaily': ['Ernest Hemingway', 'Vance Bourjaily'],
#  'Vance Bourjaily (ed.)': ['Ernest Hemingway', 'Vance Bourjaily (ed.)'],
#  'John Gregory Bourke': ['Ernest Hemingway', 'John Gregory Bourke'],
#  'Anatole Bourman': ['Ernest Hemingway', 'Anatole Bourman'],
#  'Nathaniel Bowditch': ['Ernest Hemingway', 'Nathaniel Bowditch'],
#  'James Beard': ['Ernest Hemingway', 'James Beard'],
#  'Catherine Drinker Bowen': ['Ernest Hemingway', 'Catherine Drinker Bowen'],
#  'Pierre Béarn': ['Ernest Hemingway', 'Pierre Béarn'],
#  'Norman Beasley': ['Ernest Hemingway', 'Norman Beasley'],
#  'Elizabeth Bowen': ['Ernest Hemingway', 'Elizabeth Bowen'],
#  'Cecil Walter Hardy Beaton': ['Ernest Hemingway',
#   'Cecil Walter Hardy Beaton'],
#  'Finlay Cochrane Beatson': ['Ernest Hemingway', 'Finlay Cochrane Beatson'],
#  'Edward W. Beattie': ['Ernest Hemingway', 'Edward W. Beattie'],
#  'Willard Leon Beaulac': ['Ernest Hemingway', 'Willard Leon Beaulac'],
#  'Francis Beaumont': ['Ernest Hemingway', 'Francis Beaumont'],
#  'Marjorie Bowen': ['Ernest Hemingway', 'Marjorie Bowen'],
#  'Simone de Beauvoir': ['Ernest Hemingway', 'Simone de Beauvoir'],
#  'Claude Gernade Bowers': ['Ernest Hemingway', 'Claude Gernade Bowers'],
#  'Jules Bebie': ['Ernest Hemingway', 'Jules Bebie'],
#  'José Becerra y Alvarez': ['Ernest Hemingway', 'José Becerra y Alvarez'],
#  'Carl Lotus Becker': ['Ernest Hemingway', 'Carl Lotus Becker'],
#  'Ivan Lawrence Becker': ['Ernest Hemingway', 'Ivan Lawrence Becker'],
#  'Stephen D. Becker': ['Ernest Hemingway', 'Stephen D. Becker'],
#  'Samuel Beckett': ['Ernest Hemingway', 'Samuel Beckett'],
#  'Paul Frederic Bowles': ['Ernest Hemingway', 'Paul Frederic Bowles'],
#  'Clair Francis Bee': ['Ernest Hemingway', 'Clair Francis Bee'],
#  'Lucius Morris Beebe': ['Ernest Hemingway', 'Lucius Morris Beebe'],
#  'Francis Beeding [pseud.]': ['Ernest Hemingway', 'Francis Beeding [pseud.]'],
#  'Peter Bowman': ['Ernest Hemingway', 'Peter Bowman'],
#  'Thomas Beer': ['Ernest Hemingway', 'Thomas Beer'],
#  'Max Beerbohm': ['Ernest Hemingway', 'Max Beerbohm'],
#  'Ernest Augustus Boyd': ['Ernest Hemingway', 'Ernest Augustus Boyd'],
#  'Samuel Nathaniel Behrman': ['Ernest Hemingway', 'Samuel Nathaniel Behrman'],
#  'John Bay Beith': ['Ernest Hemingway', 'John Bay Beith'],
#  'James Boyd': ['Ernest Hemingway', 'James Boyd'],
#  'James Boyd (ed.)': ['Ernest Hemingway', 'James Boyd (ed.)'],
#  'Vladimir Belayev': ['Ernest Hemingway', 'Vladimir Belayev'],
#  'Thomas Alexander Boyd': ['Ernest Hemingway', 'Thomas Alexander Boyd'],
#  'John Boyes': ['Ernest Hemingway', 'John Boyes'],
#  'Joaquin Belda': ['Ernest Hemingway', 'Joaquin Belda'],
#  'Kay Boyle': ['Ernest Hemingway', 'Kay Boyle'],
#  'Neil Boyton': ['Ernest Hemingway', 'Neil Boyton'],
#  'Charles Brackett': ['Ernest Hemingway', 'Charles Brackett'],
#  'Ray Bradbury': ['Ernest Hemingway', 'Ray Bradbury'],
#  'Russell Braddon': ['Ernest Hemingway', 'Russell Braddon'],
#  'Hugh Bradley': ['Ernest Hemingway', 'Hugh Bradley'],
#  'Fred Bradna': ['Ernest Hemingway', 'Fred Bradna'],
#  "Marc' Antonio Bragadin": ['Ernest Hemingway', "Marc' Antonio Bragadin"],
#  'Robert J. Braidwood': ['Ernest Hemingway', 'Robert J. Braidwood'],
#  'Houston Branch': ['Ernest Hemingway', 'Houston Branch'],
#  'V.C. Branham': ['Ernest Hemingway', 'V.C. Branham'],
#  'Henry C. Branson': ['Ernest Hemingway', 'Henry C. Branson'],
#  'Georges Braque': ['Ernest Hemingway', 'Georges Braque'],
#  'H.G. Thursfield (ed.)': ['Ernest Hemingway', 'H.G. Thursfield (ed.)'],
#  'Braun et Compagnie': ['Ernest Hemingway', 'Braun et Compagnie'],
#  'Nicolás Bravo': ['Ernest Hemingway', 'Nicolás Bravo'],
#  'James Henry Breasted': ['Ernest Hemingway', 'James Henry Breasted'],
#  'Winston Brebner': ['Ernest Hemingway', 'Winston Brebner'],
#  'Charles Marcus Breder': ['Ernest Hemingway', 'Charles Marcus Breder'],
#  'Harvey Breit': ['Ernest Hemingway', 'Harvey Breit'],
#  'Mary Moore Bremer': ['Ernest Hemingway', 'Mary Moore Bremer'],
#  'Gerald Brenan': ['Ernest Hemingway', 'Gerald Brenan'],
#  'Edin Brenes': ['Ernest Hemingway', 'Edin Brenes'],
#  'Fresia Brenes de Hilarov': ['Ernest Hemingway', 'Fresia Brenes de Hilarov'],
#  'Dan Brennan': ['Ernest Hemingway', 'Dan Brennan'],
#  'Anita Brenner': ['Ernest Hemingway', 'Anita Brenner'],
#  'André Breton': ['Ernest Hemingway', 'André Breton'],
#  'Bessie Breuer': ['Ernest Hemingway', 'Bessie Breuer'],
#  'Jack Belden': ['Ernest Hemingway', 'Jack Belden'],
#  'Aubrey Fitz Gerald Bell': ['Ernest Hemingway', 'Aubrey Fitz Gerald Bell'],
#  'Douglas Herbert Bell': ['Ernest Hemingway', 'Douglas Herbert Bell'],
#  'Ed Bell': ['Ernest Hemingway', 'Ed Bell'],
#  'Frederick Jackson Bell': ['Ernest Hemingway', 'Frederick Jackson Bell'],
#  'Gertrude Lowthian Bell': ['Ernest Hemingway', 'Gertrude Lowthian Bell'],
#  'Hugh MacLachlan Bell': ['Ernest Hemingway', 'Hugh MacLachlan Bell'],
#  'Walter Dalrymple Maitland Bell': ['Ernest Hemingway',
#   'Walter Dalrymple Maitland Bell'],
#  'Henry Bellamann': ['Ernest Hemingway', 'Henry Bellamann'],
#  'Hilaire Belloc': ['Ernest Hemingway', 'Hilaire Belloc'],
#  'José María Belloch Puig': ['Ernest Hemingway', 'José María Belloch Puig'],
#  'Maria Bellonci': ['Ernest Hemingway', 'Maria Bellonci'],
#  'Felice Bellotti': ['Ernest Hemingway', 'Felice Bellotti'],
#  'Saul Bellow': ['Ernest Hemingway', 'Saul Bellow'],
#  'George Wesley Bellows': ['Ernest Hemingway', 'George Wesley Bellows'],
#  'Joaquín Bellsolá': ['Ernest Hemingway', 'Joaquín Bellsolá'],
#  'Jacques Vital Belmas': ['Ernest Hemingway', 'Jacques Vital Belmas'],
#  'Juan Belmonte y García': ['Ernest Hemingway', 'Juan Belmonte y García'],
#  'Guy Belzacq': ['Ernest Hemingway', 'Guy Belzacq'],
#  'Ludwig Bemelmans': ['Ernest Hemingway', 'Ludwig Bemelmans'],
#  'Victor Breyer': ['Ernest Hemingway', 'Victor Breyer'],
#  'Herschel Brickell (ed.)': ['Ernest Hemingway', 'Herschel Brickell (ed.)'],
#  'Richard Max Brickner': ['Ernest Hemingway', 'Richard Max Brickner'],
#  'Clare A. Briggs': ['Ernest Hemingway', 'Clare A. Briggs'],
#  'Ellis O. Briggs': ['Ernest Hemingway', 'Ellis O. Briggs'],
#  'Robert Bright': ['Ernest Hemingway', 'Robert Bright'],
#  'Jean Anthelme Brillat-Savarin': ['Ernest Hemingway',
#   'Jean Anthelme Brillat-Savarin'],
#  'William Brinkley': ['Ernest Hemingway', 'William Brinkley'],
#  'John Malcolm Brinnin': ['Ernest Hemingway', 'John Malcolm Brinnin'],
#  'Lilyan Brock': ['Ernest Hemingway', 'Lilyan Brock'],
#  'Ray Brock': ['Ernest Hemingway', 'Ray Brock'],
#  'Manuel D. Benavides': ['Ernest Hemingway', 'Manuel D. Benavides'],
#  'Wallace Brockway': ['Ernest Hemingway', 'Wallace Brockway'],
#  'Alter Brody (ed.)': ['Ernest Hemingway', 'Alter Brody (ed.)'],
#  'Nathaniel Benchley': ['Ernest Hemingway', 'Nathaniel Benchley'],
#  'Robert Benchley': ['Ernest Hemingway', 'Robert Benchley'],
#  'Iles Brody': ['Ernest Hemingway', 'Iles Brody'],
#  'Julien Benda': ['Ernest Hemingway', 'Julien Benda'],
#  'Robert Bendiner': ['Ernest Hemingway', 'Robert Bendiner'],
#  'A. W. Brøgger': ['Ernest Hemingway', 'A. W. Brøgger'],
#  'Ruth Benedict': ['Ernest Hemingway', 'Ruth Benedict'],
#  'Vojta Bene_': ['Ernest Hemingway', 'Vojta Bene_'],
#  'Stephen Vincent Benét': ['Ernest Hemingway', 'Stephen Vincent Benét'],
#  'Eduardo Benet y Castellón': ['Ernest Hemingway',
#   'Eduardo Benet y Castellón'],
#  'Frans Gunnar Bengtsson': ['Ernest Hemingway', 'Frans Gunnar Bengtsson'],
#  'Louis Bromfield': ['Ernest Hemingway', 'Louis Bromfield'],
#  'Sir William Gurney Benham': ['Ernest Hemingway',
#   'Sir William Gurney Benham'],
#  'René Benjamin': ['Ernest Hemingway', 'René Benjamin'],
#  'Arnold Bennett': ['Ernest Hemingway', 'Arnold Bennett'],
#  'Joan Bennett': ['Ernest Hemingway', 'Joan Bennett'],
#  'Bertrand Harris Bronson (ed.)': ['Ernest Hemingway',
#   'Bertrand Harris Bronson (ed.)'],
#  'Jean-Jacques Bronsson': ['Ernest Hemingway', 'Jean-Jacques Bronsson'],
#  'Charlotte Brontë': ['Ernest Hemingway', 'Charlotte Brontë'],
#  'Emily Brontë': ['Ernest Hemingway', 'Emily Brontë'],
#  'Rupert Brooke': ['Ernest Hemingway', 'Rupert Brooke'],
#  'Alden Brooks': ['Ernest Hemingway', 'Alden Brooks'],
#  'John Nixon Brooks': ['Ernest Hemingway', 'John Nixon Brooks'],
#  'Van Wyck Brooks': ['Ernest Hemingway', 'Van Wyck Brooks'],
#  'Win Brooks': ['Ernest Hemingway', 'Win Brooks'],
#  'Jim Brosnan': ['Ernest Hemingway', 'Jim Brosnan'],
#  'Chandler Brossard': ['Ernest Hemingway', 'Chandler Brossard'],
#  'Bruce Brown': ['Ernest Hemingway', 'Bruce Brown'],
#  'Cecil Brown': ['Ernest Hemingway', 'Cecil Brown'],
#  'Dee Alexander Brown': ['Ernest Hemingway', 'Dee Alexander Brown'],
#  "Harry Peter M'Nab Brown": ['Ernest Hemingway', "Harry Peter M'Nab Brown"],
#  'Horatio Robert Forbes Brown': ['Ernest Hemingway',
#   'Horatio Robert Forbes Brown'],
#  'Joe David Brown': ['Ernest Hemingway', 'Joe David Brown'],
#  'John Brown': ['Ernest Hemingway', 'John Brown'],
#  'John Lackey Brown': ['Ernest Hemingway', 'John Lackey Brown'],
#  'John Hart Brown': ['Ernest Hemingway', 'John Hart Brown'],
#  'Lloyd Arnold Brown': ['Ernest Hemingway', 'Lloyd Arnold Brown'],
#  'Pete Brown': ['Ernest Hemingway', 'Pete Brown'],
#  'Rollo Walter Brown (ed.)': ['Ernest Hemingway', 'Rollo Walter Brown (ed.)'],
#  'Warren Brown': ['Ernest Hemingway', 'Warren Brown'],
#  'Wenzell Brown': ['Ernest Hemingway', 'Wenzell Brown'],
#  'Zenith [Leslie Ford] Brown': ['Ernest Hemingway',
#   'Zenith [Leslie Ford] Brown'],
#  'Russell H. Bennett': ['Ernest Hemingway', 'Russell H. Bennett'],
#  'Fernand Benoît': ['Ernest Hemingway', 'Fernand Benoît'],
#  'Pierre Benoit': ['Ernest Hemingway', 'Pierre Benoit'],
#  'Edward Frederick Benson': ['Ernest Hemingway', 'Edward Frederick Benson'],
#  'Stella Benson': ['Ernest Hemingway', 'Stella Benson'],
#  'Newell Bent': ['Ernest Hemingway', 'Newell Bent'],
#  'Edmund Clerihew Bentley': ['Ernest Hemingway', 'Edmund Clerihew Bentley'],
#  'John Bentley': ['Ernest Hemingway', 'John Bentley'],
#  'Felice Benuzzi': ['Ernest Hemingway', 'Felice Benuzzi'],
#  'Paul Benzaquin': ['Ernest Hemingway', 'Paul Benzaquin'],
#  'Henri Béraud': ['Ernest Hemingway', 'Henri Béraud'],
#  'Bernard Berenson': ['Ernest Hemingway', 'Bernard Berenson'],
#  'Marc Brandel': ['Ernest Hemingway', 'Marc Brandel'],
#  'Seton Robert de la Poer Beresford': ['Ernest Hemingway',
#   'Seton Robert de la Poer Beresford'],
#  'Bengt Magnus Kristoffer Berg': ['Ernest Hemingway',
#   'Bengt Magnus Kristoffer Berg'],
#  'José Bergamín': ['Ernest Hemingway', 'José Bergamín'],
#  'Ray Bergman': ['Ernest Hemingway', 'Ray Bergman'],
#  'Edgar Bérillon': ['Ernest Hemingway', 'Edgar Bérillon'],
#  'Isaiah Berlin': ['Ernest Hemingway', 'Isaiah Berlin'],
#  'Maximilian Delphinus Berlitz': ['Ernest Hemingway',
#   'Maximilian Delphinus Berlitz'],
#  'Theos Bernard': ['Ernest Hemingway', 'Theos Bernard'],
#  'Tristan Bernard': ['Ernest Hemingway', 'Tristan Bernard'],
#  'Carlo Bernari': ['Ernest Hemingway', 'Carlo Bernari'],
#  'Hubert J. Bernhard': ['Ernest Hemingway', 'Hubert J. Bernhard'],
#  'Molly Bernheim': ['Ernest Hemingway', 'Molly Bernheim'],
#  'Leonard Bernstein': ['Ernest Hemingway', 'Leonard Bernstein'],
#  'Victor Heine Bernstein': ['Ernest Hemingway', 'Victor Heine Bernstein'],
#  'Edith Berrien': ['Ernest Hemingway', 'Edith Berrien'],
#  'Michael Agerskov (ed.)': ['Ernest Hemingway', 'Michael Agerskov (ed.)'],
#  'Víctor Agostini': ['Ernest Hemingway', 'Víctor Agostini'],
#  'José Antonio de Aguirre y Lecube': ['Ernest Hemingway',
#   'José Antonio de Aguirre y Lecube'],
#  'Chulam Ahmad': ['Ernest Hemingway', 'Chulam Ahmad'],
#  'Conrad Aiken': ['Ernest Hemingway', 'Conrad Aiken'],
#  'Duncan Aikman': ['Ernest Hemingway', 'Duncan Aikman'],
#  'Carl Ethan Akeley': ['Ernest Hemingway', 'Carl Ethan Akeley'],
#  'Mary L. Jobe Akeley': ['Ernest Hemingway', 'Mary L. Jobe Akeley'],
#  'Douglas Gordon Browne': ['Ernest Hemingway', 'Douglas Gordon Browne'],
#  'Thomas Alexander [Rolf Boldrewood] Browne': ['Ernest Hemingway',
#   'Thomas Alexander [Rolf Boldrewood] Browne'],
#  'Robert Browning': ['Ernest Hemingway', 'Robert Browning'],
#  'E.A. Brubacher': ['Ernest Hemingway', 'E.A. Brubacher'],
#  'Ethel Sutton Bruce': ['Ernest Hemingway', 'Ethel Sutton Bruce'],
#  'Raymond Léopold Bruckberger': ['Ernest Hemingway',
#   'Raymond Léopold Bruckberger'],
#  'Pieter Brueghel': ['Ernest Hemingway', 'Pieter Brueghel'],
#  'William Arthur Bruette': ['Ernest Hemingway', 'William Arthur Bruette'],
#  'Stephen Cole Bruner': ['Ernest Hemingway', 'Stephen Cole Bruner'],
#  'Katharine Brush': ['Ernest Hemingway', 'Katharine Brush'],
#  'George Sands Bryan': ['Ernest Hemingway', 'George Sands Bryan'],
#  'Joseph Bryan': ['Ernest Hemingway', 'Joseph Bryan'],
#  'Arthur Bryant': ['Ernest Hemingway', 'Arthur Bryant'],
#  'Doris Bryant': ['Ernest Hemingway', 'Doris Bryant'],
#  'Martin Buber': ['Ernest Hemingway', 'Martin Buber'],
#  'Pier Luigi Bucciantini': ['Ernest Hemingway', 'Pier Luigi Bucciantini'],
#  'John Buchan': ['Ernest Hemingway', 'John Buchan'],
#  "William James de l'Aigle Buchan": ['Ernest Hemingway',
#   "William James de l'Aigle Buchan"],
#  'Lamont Buchanan': ['Ernest Hemingway', 'Lamont Buchanan'],
#  'Art Buchwald': ['Ernest Hemingway', 'Art Buchwald'],
#  'Pearl S. Buck': ['Ernest Hemingway', 'Pearl S. Buck'],
#  'William Buckland': ['Ernest Hemingway', 'William Buckland'],
#  'Henry W. Buckley': ['Ernest Hemingway', 'Henry W. Buckley'],
#  'Peter Buckley': ['Ernest Hemingway', 'Peter Buckley'],
#  'Luigi Vittorio Bertarelli': ['Ernest Hemingway',
#   'Luigi Vittorio Bertarelli'],
#  'William F. Buckley': ['Ernest Hemingway', 'William F. Buckley'],
#  'Jules Bertaut': ['Ernest Hemingway', 'Jules Bertaut'],
#  'Giuseppe Berto': ['Ernest Hemingway', 'Giuseppe Berto'],
#  'Kate Bertram': ['Ernest Hemingway', 'Kate Bertram'],
#  'Donald Budge': ['Ernest Hemingway', 'Donald Budge'],
#  'comte Henri-Gratien Bertrand': ['Ernest Hemingway',
#   'comte Henri-Gratien Bertrand'],
#  'Charles Bugnet': ['Ernest Hemingway', 'Charles Bugnet'],
#  'Alvah Cecil Bessie': ['Ernest Hemingway', 'Alvah Cecil Bessie'],
#  'Thomas Bulfinch': ['Ernest Hemingway', 'Thomas Bulfinch'],
#  'George Besson': ['Ernest Hemingway', 'George Besson'],
#  'Odón Betanzos Palacios': ['Ernest Hemingway', 'Odón Betanzos Palacios'],
#  'Odon Betanzos Palacios': ['Ernest Hemingway', 'Odon Betanzos Palacios'],
#  'Clarence Joseph Bulliet': ['Ernest Hemingway', 'Clarence Joseph Bulliet'],
#  'Henry Lewis Betten': ['Ernest Hemingway', 'Henry Lewis Betten'],
#  'Enzo Bettiza': ['Ernest Hemingway', 'Enzo Bettiza'],
#  'Thomas Victor Bulpin': ['Ernest Hemingway', 'Thomas Victor Bulpin'],
#  'Jean de Beucken': ['Ernest Hemingway', 'Jean de Beucken'],
#  'André Beucler': ['Ernest Hemingway', 'André Beucler'],
#  'Marie Henri Beyle': ['Ernest Hemingway', 'Marie Henri Beyle'],
#  'Bungei Shunj_ Shinsha': ['Ernest Hemingway', 'Bungei Shunj_ Shinsha'],
#  'Stendhal': ['Ernest Hemingway', 'Stendhal'],
#  'Joel William Bunkley': ['Ernest Hemingway', 'Joel William Bunkley'],
#  'Albert Isaac Bezzerides': ['Ernest Hemingway', 'Albert Isaac Bezzerides'],
#  'Adriana Ivancich Biaggini': ['Ernest Hemingway',
#   'Adriana Ivancich Biaggini'],
#  'Michael Bialoguski': ['Ernest Hemingway', 'Michael Bialoguski'],
#  'Leonida Biancolini': ['Ernest Hemingway', 'Leonida Biancolini'],
#  'Karl August Bickel': ['Ernest Hemingway', 'Karl August Bickel'],
#  'Ellis Parker Butler': ['Ernest Hemingway', 'Ellis Parker Butler'],
#  'Frank Hedges Butler': ['Ernest Hemingway', 'Frank Hedges Butler'],
#  'Samuel Butler': ['Ernest Hemingway', 'Samuel Butler'],
#  'Oreste del Buono': ['Ernest Hemingway', 'Oreste del Buono'],
#  'John P. Burch': ['Ernest Hemingway', 'John P. Burch'],
#  'Mary Butts': ['Ernest Hemingway', 'Mary Butts'],
#  'Earl Buxton': ['Ernest Hemingway', 'Earl Buxton'],
#  'Edward North Buxton': ['Ernest Hemingway', 'Edward North Buxton'],
#  'Jacob Christoph Burckhardt': ['Ernest Hemingway',
#   'Jacob Christoph Burckhardt'],
#  'Francis Henry Buzzacott': ['Ernest Hemingway', 'Francis Henry Buzzacott'],
#  'Arthur Byne': ['Ernest Hemingway', 'Arthur Byne'],
#  'Eugene Burdick': ['Ernest Hemingway', 'Eugene Burdick'],
#  'Witter Bynner': ['Ernest Hemingway', 'Witter Bynner'],
#  'Donn Byrne': ['Ernest Hemingway', 'Donn Byrne'],
#  'Richard Lloyd Burdsall': ['Ernest Hemingway', 'Richard Lloyd Burdsall'],
#  'Lord George Gordon Byron': ['Ernest Hemingway', 'Lord George Gordon Byron'],
#  'Alan Burgess': ['Ernest Hemingway', 'Alan Burgess'],
#  'Edwin Berry Burgum': ['Ernest Hemingway', 'Edwin Berry Burgum'],
#  'Thomas Burke': ['Ernest Hemingway', 'Thomas Burke'],
#  'J.B. Burlace (ed.)': ['Ernest Hemingway', 'J.B. Burlace (ed.)'],
#  'Baron George Gordon Byron Byron': ['Ernest Hemingway',
#   'Baron George Gordon Byron Byron'],
#  'James Branch Cabell': ['Ernest Hemingway', 'James Branch Cabell'],
#  'Will Cadby': ['Ernest Hemingway', 'Will Cadby'],
#  'Raffaele Cadorna': ['Ernest Hemingway', 'Raffaele Cadorna'],
#  'Martin Caidin': ['Ernest Hemingway', 'Martin Caidin'],
#  'James Mallahan Cain': ['Ernest Hemingway', 'James Mallahan Cain'],
#  'Louis S. Caine': ['Ernest Hemingway', 'Louis S. Caine'],
#  'Arthur Calder-Marshall': ['Ernest Hemingway', 'Arthur Calder-Marshall'],
#  'Erskine Caldwell': ['Ernest Hemingway', 'Erskine Caldwell'],
#  'Taylor Caldwell': ['Ernest Hemingway', 'Taylor Caldwell'],
#  'Charles J. Calitri': ['Ernest Hemingway', 'Charles J. Calitri'],
#  'Earnest Elmo Calkins': ['Ernest Hemingway', 'Earnest Elmo Calkins'],
#  'Morley Callaghan': ['Ernest Hemingway', 'Morley Callaghan'],
#  'Parnell Joseph Terence Callahan': ['Ernest Hemingway',
#   'Parnell Joseph Terence Callahan'],
#  'Sir Charles Edward Callwell': ['Ernest Hemingway',
#   'Sir Charles Edward Callwell'],
#  'Edgar Calmer': ['Ernest Hemingway', 'Edgar Calmer'],
#  'Ned Calmer': ['Ernest Hemingway', 'Ned Calmer'],
#  'Michael Calvert': ['Ernest Hemingway', 'Michael Calvert'],
#  'Italo Calvino': ['Ernest Hemingway', 'Italo Calvino'],
#  'Roger Burlingame': ['Ernest Hemingway', 'Roger Burlingame'],
#  'Ricardo Calvo Martínez': ['Ernest Hemingway', 'Ricardo Calvo Martínez'],
#  'Ben Lucien Burman': ['Ernest Hemingway', 'Ben Lucien Burman'],
#  'Roderick William Cameron': ['Ernest Hemingway', 'Roderick William Cameron'],
#  'Michael Burn': ['Ernest Hemingway', 'Michael Burn'],
#  'Robert [Robert-Robert] Burnand': ['Ernest Hemingway',
#   'Robert [Robert-Robert] Burnand'],
#  'Luiz de Camões': ['Ernest Hemingway', 'Luiz de Camões'],
#  'Tony Burnand': ['Ernest Hemingway', 'Tony Burnand'],
#  'Luis de Camões': ['Ernest Hemingway', 'Luis de Camões'],
#  'Luís de Camões': ['Ernest Hemingway', 'Luís de Camões'],
#  'Gordon Campbell': ['Ernest Hemingway', 'Gordon Campbell'],
#  'Alfred Higgins Burne': ['Ernest Hemingway', 'Alfred Higgins Burne'],
#  'Roy Campbell': ['Ernest Hemingway', 'Roy Campbell'],
#  'Hallie Southgate Burnett': ['Ernest Hemingway', 'Hallie Southgate Burnett'],
#  'Robert Burnett': ['Ernest Hemingway', 'Robert Burnett'],
#  'Whit Burnett': ['Ernest Hemingway', 'Whit Burnett'],
#  'Whit Burnett (ed.)': ['Ernest Hemingway', 'Whit Burnett (ed.)'],
#  'William Riley Burnett': ['Ernest Hemingway', 'William Riley Burnett'],
#  'William Edward March Campbell': ['Ernest Hemingway',
#   'William Edward March Campbell'],
#  'Jorge Campos': ['Ernest Hemingway', 'Jorge Campos'],
#  'Albert Camus': ['Ernest Hemingway', 'Albert Camus'],
#  'Canadian National Exhibition': ['Ernest Hemingway',
#   'Canadian National Exhibition'],
#  'Francisco Candel': ['Ernest Hemingway', 'Francisco Candel'],
#  'Elias Canetti': ['Ernest Hemingway', 'Elias Canetti'],
#  'Victor Canning': ['Ernest Hemingway', 'Victor Canning'],
#  'James J. Cannon': ['Ernest Hemingway', 'James J. Cannon'],
#  'Christopher Burney': ['Ernest Hemingway', 'Christopher Burney'],
#  'David Burnham': ['Ernest Hemingway', 'David Burnham'],
#  'Frederick Russell Burnham': ['Ernest Hemingway',
#   'Frederick Russell Burnham'],
#  'James Burnham': ['Ernest Hemingway', 'James Burnham'],
#  'Eugene Burns': ['Ernest Hemingway', 'Eugene Burns'],
#  'Walter Noble Burns': ['Ernest Hemingway', 'Walter Noble Burns'],
#  'Sir Gerald Burrard': ['Ernest Hemingway', 'Sir Gerald Burrard'],
#  'Katharine Burt': ['Ernest Hemingway', 'Katharine Burt'],
#  'Maxwell Struthers Burt': ['Ernest Hemingway', 'Maxwell Struthers Burt'],
#  'Charles Pierce Burton': ['Ernest Hemingway', 'Charles Pierce Burton'],
#  'Elizabeth Burton': ['Ernest Hemingway', 'Elizabeth Burton'],
#  'Jean Burton': ['Ernest Hemingway', 'Jean Burton'],
#  'Sir Richard Francis Burton': ['Ernest Hemingway',
#   'Sir Richard Francis Burton'],
#  'Ernst Busch (ed.)': ['Ernest Hemingway', 'Ernst Busch (ed.)'],
#  'Francis Xavier Busch': ['Ernest Hemingway', 'Francis Xavier Busch'],
#  'Wilhelm Busch': ['Ernest Hemingway', 'Wilhelm Busch'],
#  'Louise Bush-Brown': ['Ernest Hemingway', 'Louise Bush-Brown'],
#  'Kate Buss': ['Ernest Hemingway', 'Kate Buss'],
#  'Miguel J. Bustos Cerecedo': ['Ernest Hemingway',
#   'Miguel J. Bustos Cerecedo'],
#  'Harry Cecil Butcher': ['Ernest Hemingway', 'Harry Cecil Butcher'],
#  'Elmer Ellis': ['Ernest Hemingway', 'Elmer Ellis'],
#  'Havelock Ellis': ['Ernest Hemingway', 'Havelock Ellis'],
#  'Richard Ellmann': ['Ernest Hemingway', 'Richard Ellmann'],
#  'Edward Ellsberg': ['Ernest Hemingway', 'Edward Ellsberg'],
#  'Hal Ellson': ['Ernest Hemingway', 'Hal Ellson'],
#  'Lincoln Ellsworth': ['Ernest Hemingway', 'Lincoln Ellsworth'],
#  'Joseph van der Elst': ['Ernest Hemingway', 'Joseph van der Elst'],
#  'Allan Vaughan Elston': ['Ernest Hemingway', 'Allan Vaughan Elston'],
#  'Paul Eluard': ['Ernest Hemingway', 'Paul Eluard'],
#  'Harold Elvin': ['Ernest Hemingway', 'Harold Elvin'],
#  'Peter Henry Emerson': ['Ernest Hemingway', 'Peter Henry Emerson'],
#  'S. Guy Endore': ['Ernest Hemingway', 'S. Guy Endore'],
#  'Louis Engel': ['Ernest Hemingway', 'Louis Engel'],
#  'Stuart David Engstrand': ['Ernest Hemingway', 'Stuart David Engstrand'],
#  'George Pearse Ennis': ['Ernest Hemingway', 'George Pearse Ennis'],
#  'Enrique C. Henríquez': ['Ernest Hemingway', 'Enrique C. Henríquez'],
#  'Angna Enters': ['Ernest Hemingway', 'Angna Enters'],
#  'Emile Erckmann': ['Ernest Hemingway', 'Emile Erckmann'],
#  'Clayton Holt Ernst (ed.)': ['Ernest Hemingway', 'Clayton Holt Ernst (ed.)'],
#  'Morris Leopold Ernst': ['Ernest Hemingway', 'Morris Leopold Ernst'],
#  'John Erskine': ['Ernest Hemingway', 'John Erskine'],
#  'Viscount Reginald Baliol Brett Esher': ['Ernest Hemingway',
#   'Viscount Reginald Baliol Brett Esher'],
#  'España. Ministerio de Agricultura': ['Ernest Hemingway',
#   'España. Ministerio de Agricultura'],
#  'Esquire': ['Ernest Hemingway', 'Esquire'],
#  'Charles Estienne': ['Ernest Hemingway', 'Charles Estienne'],
#  'Fred Etchen': ['Ernest Hemingway', 'Fred Etchen'],
#  'Harold Ettlinger': ['Ernest Hemingway', 'Harold Ettlinger'],
#  'Euripides': ['Ernest Hemingway', 'Euripides'],
#  'Vlad Evanoff': ['Ernest Hemingway', 'Vlad Evanoff'],
#  'R. Tenniel Evans': ['Ernest Hemingway', 'R. Tenniel Evans'],
#  'Hal G. Evarts': ['Ernest Hemingway', 'Hal G. Evarts'],
#  'Robert Cantwell': ['Ernest Hemingway', 'Robert Cantwell'],
#  'Robert Capa': ['Ernest Hemingway', 'Robert Capa'],
#  'José María Capdevila Marca': ['Ernest Hemingway',
#   'José María Capdevila Marca'],
#  'Truman Capote': ['Ernest Hemingway', 'Truman Capote'],
#  'Ferruccia Cappi Bentivegna': ['Ernest Hemingway',
#   'Ferruccia Cappi Bentivegna'],
#  'Reyes Carbonell': ['Ernest Hemingway', 'Reyes Carbonell'],
#  'Francis Carco': ['Ernest Hemingway', 'Francis Carco'],
#  'Harold G. Cardozo': ['Ernest Hemingway', 'Harold G. Cardozo'],
#  'Paul Carell': ['Ernest Hemingway', 'Paul Carell'],
#  'Benjamin Carlin': ['Ernest Hemingway', 'Benjamin Carlin'],
#  'Donald Thompson Carlisle': ['Ernest Hemingway', 'Donald Thompson Carlisle'],
#  'Evans Fordyce Carlson': ['Ernest Hemingway', 'Evans Fordyce Carlson'],
#  'Thomas Carlyle': ['Ernest Hemingway', 'Thomas Carlyle'],
#  'Carl Lamson Carmer': ['Ernest Hemingway', 'Carl Lamson Carmer'],
#  'Hoagy Carmichael': ['Ernest Hemingway', 'Hoagy Carmichael'],
#  'Angel Carmona': ['Ernest Hemingway', 'Angel Carmona'],
#  'Dale Carnegie': ['Ernest Hemingway', 'Dale Carnegie'],
#  'Cecil Carnes': ['Ernest Hemingway', 'Cecil Carnes'],
#  'Margaret Carpenter': ['Ernest Hemingway', 'Margaret Carpenter'],
#  'Alejo Carpentier': ['Ernest Hemingway', 'Alejo Carpentier'],
#  'Georges Carpentier': ['Ernest Hemingway', 'Georges Carpentier'],
#  'Edward Hallett Carr': ['Ernest Hemingway', 'Edward Hallett Carr'],
#  'John Dickson Carr': ['Ernest Hemingway', 'John Dickson Carr'],
#  'Katie M. Carr': ['Ernest Hemingway', 'Katie M. Carr'],
#  'Peter Carr': ['Ernest Hemingway', 'Peter Carr'],
#  'Philip Carr': ['Ernest Hemingway', 'Philip Carr'],
#  'José Carralero': ['Ernest Hemingway', 'José Carralero'],
#  'Jorge Carrera Andrade': ['Ernest Hemingway', 'Jorge Carrera Andrade'],
#  'Francesco Carreras y Candi': ['Ernest Hemingway',
#   'Francesco Carreras y Candi'],
#  'Louis Carrère': ['Ernest Hemingway', 'Louis Carrère'],
#  'José María Carretero': ['Ernest Hemingway', 'José María Carretero'],
#  'Constance Carrier': ['Ernest Hemingway', 'Constance Carrier'],
#  'Warren Pendleton Carrier': ['Ernest Hemingway', 'Warren Pendleton Carrier'],
#  'Raffaele Carrieri': ['Ernest Hemingway', 'Raffaele Carrieri'],
#  'Sally Carrighar': ['Ernest Hemingway', 'Sally Carrighar'],
#  'Charles Edmund Carrington': ['Ernest Hemingway',
#   'Charles Edmund Carrington'],
#  'Gordon Carroll': ['Ernest Hemingway', 'Gordon Carroll'],
#  'John Alexander Carroll': ['Ernest Hemingway', 'John Alexander Carroll'],
#  'Hayden Carruth': ['Ernest Hemingway', 'Hayden Carruth'],
#  'Robert Carse': ['Ernest Hemingway', 'Robert Carse'],
#  'Bart Carson': ['Ernest Hemingway', 'Bart Carson'],
#  'Rachel Louise Carson': ['Ernest Hemingway', 'Rachel Louise Carson'],
#  'Robert Carson': ['Ernest Hemingway', 'Robert Carson'],
#  'Carroll Carstairs': ['Ernest Hemingway', 'Carroll Carstairs'],
#  'Catherine MacFarlane Carswell': ['Ernest Hemingway',
#   'Catherine MacFarlane Carswell'],
#  'Ernestine Carter': ['Ernest Hemingway', 'Ernestine Carter'],
#  'John Carter': ['Ernest Hemingway', 'John Carter'],
#  'Thomas Donald Carter': ['Ernest Hemingway', 'Thomas Donald Carter'],
#  'J. D. Carthy': ['Ernest Hemingway', 'J. D. Carthy'],
#  'A. P. Cartwright': ['Ernest Hemingway', 'A. P. Cartwright'],
#  'Dorothy Park Caruso': ['Ernest Hemingway', 'Dorothy Park Caruso'],
#  'Joyce Cary': ['Ernest Hemingway', 'Joyce Cary'],
#  'Rocca Casciano': ['Ernest Hemingway', 'Rocca Casciano'],
#  'Lee Taylor Casey': ['Ernest Hemingway', 'Lee Taylor Casey'],
#  'Robert J. Casey': ['Ernest Hemingway', 'Robert J. Casey'],
#  'Lionel Casson': ['Ernest Hemingway', 'Lionel Casson'],
#  'Stanley Casson': ['Ernest Hemingway', 'Stanley Casson'],
#  'J. Castaréde': ['Ernest Hemingway', 'J. Castaréde'],
#  'Emanuele di Castelbarco': ['Ernest Hemingway', 'Emanuele di Castelbarco'],
#  'José María Castellet': ['Ernest Hemingway', 'José María Castellet'],
#  'Gonzalo Castilla': ['Ernest Hemingway', 'Gonzalo Castilla'],
#  'José Maria Castillo Navarro': ['Ernest Hemingway',
#   'José Maria Castillo Navarro'],
#  'José Luis Castillo Puche': ['Ernest Hemingway', 'José Luis Castillo Puche'],
#  'Josué de Castro': ['Ernest Hemingway', 'Josué de Castro'],
#  'Manuel Castro': ['Ernest Hemingway', 'Manuel Castro'],
#  'Teresa Casuso': ['Ernest Hemingway', 'Teresa Casuso'],
#  'John Caswell': ['Ernest Hemingway', 'John Caswell'],
#  'Willa Cather': ['Ernest Hemingway', 'Willa Cather'],
#  'Bruce Catton': ['Ernest Hemingway', 'Bruce Catton'],
#  'duc de Vicence Armand-Augustin-Louis de Caulaincourt': ['Ernest Hemingway',
#   'duc de Vicence Armand-Augustin-Louis de Caulaincourt'],
#  'Vivian Caulfeild': ['Ernest Hemingway', 'Vivian Caulfeild'],
#  'Germán Cavelier': ['Ernest Hemingway', 'Germán Cavelier'],
#  'Emilio Cecchi': ['Ernest Hemingway', 'Emilio Cecchi'],
#  'David Cecil': ['Ernest Hemingway', 'David Cecil'],
#  'Lord David Cecil': ['Ernest Hemingway', 'Lord David Cecil'],
#  'Camilo José Cela': ['Ernest Hemingway', 'Camilo José Cela'],
#  'Benvenuto Cellini': ['Ernest Hemingway', 'Benvenuto Cellini'],
#  'Blaise Cendrars': ['Ernest Hemingway', 'Blaise Cendrars'],
#  'Miguel de Cervantes': ['Ernest Hemingway', 'Miguel de Cervantes'],
#  'Alba de Cèspedes': ['Ernest Hemingway', 'Alba de Cèspedes'],
#  'Marc Chadourne': ['Ernest Hemingway', 'Marc Chadourne'],
#  'Serge_ Chakhotin': ['Ernest Hemingway', 'Serge_ Chakhotin'],
#  'Patrick R. Chalmers': ['Ernest Hemingway', 'Patrick R. Chalmers'],
#  'Thomas Wightman Chalmers': ['Ernest Hemingway', 'Thomas Wightman Chalmers'],
#  'Tom T. Chamales': ['Ernest Hemingway', 'Tom T. Chamales'],
#  'Samuel Chamberlain': ['Ernest Hemingway', 'Samuel Chamberlain'],
#  'Elwyn Whitman Chambers': ['Ernest Hemingway', 'Elwyn Whitman Chambers'],
#  'Whittaker Chambers': ['Ernest Hemingway', 'Whittaker Chambers'],
#  'Charles Adolphe Pineton Marquis de Chambrun': ['Ernest Hemingway',
#   'Charles Adolphe Pineton Marquis de Chambrun'],
#  'Bernard Champigneulle': ['Ernest Hemingway', 'Bernard Champigneulle'],
#  'Frederick Walter Champion': ['Ernest Hemingway',
#   'Frederick Walter Champion'],
#  'Félicien Champsaur': ['Ernest Hemingway', 'Félicien Champsaur'],
#  'Shou Ch_ên': ['Ernest Hemingway', 'Shou Ch_ên'],
#  'Raymond Chandler': ['Ernest Hemingway', 'Raymond Chandler'],
#  'John Canfield Ewers': ['Ernest Hemingway', 'John Canfield Ewers'],
#  'Juliana Horatia Ewing': ['Ernest Hemingway', 'Juliana Horatia Ewing'],
#  'Eileen Chang': ['Ernest Hemingway', 'Eileen Chang'],
#  'Warren Eyster': ['Ernest Hemingway', 'Warren Eyster'],
#  'Hsin-hai Chang': ['Ernest Hemingway', 'Hsin-hai Chang'],
#  'André Chamson': ['Ernest Hemingway', 'André Chamson'],
#  'Pu-wei Yang Chao': ['Ernest Hemingway', 'Pu-wei Yang Chao'],
#  'Frères Fabius': ['Ernest Hemingway', 'Frères Fabius'],
#  'James Paul Chapin': ['Ernest Hemingway', 'James Paul Chapin'],
#  'Ralph Chaplin': ['Ernest Hemingway', 'Ralph Chaplin'],
#  'Abel Chapman': ['Ernest Hemingway', 'Abel Chapman'],
#  'Edward Arnold Chapman': ['Ernest Hemingway', 'Edward Arnold Chapman'],
#  'Frank Michler Chapman': ['Ernest Hemingway', 'Frank Michler Chapman'],
#  'Alfred [Jacques Sindral] Fabre-Luce': ['Ernest Hemingway',
#   'Alfred [Jacques Sindral] Fabre-Luce'],
#  'Frederick Spencer Chapman': ['Ernest Hemingway',
#   'Frederick Spencer Chapman'],
#  'Guy Chapman': ['Ernest Hemingway', 'Guy Chapman'],
#  'Francisco Fabricio Diaz': ['Ernest Hemingway', 'Francisco Fabricio Diaz'],
#  'Clifton Fadiman': ['Ernest Hemingway', 'Clifton Fadiman'],
#  'John Jay Chapman': ['Ernest Hemingway', 'John Jay Chapman'],
#  'Wilbert McLeod Chapman': ['Ernest Hemingway', 'Wilbert McLeod Chapman'],
#  'Robert Charbonneau': ['Ernest Hemingway', 'Robert Charbonneau'],
#  'D. E. Charlwood': ['Ernest Hemingway', 'D. E. Charlwood'],
#  'Clifton Fadiman (ed.)': ['Ernest Hemingway', 'Clifton Fadiman (ed.)'],
#  'Allan Chase': ['Ernest Hemingway', 'Allan Chase'],
#  'Ilka Chase': ['Ernest Hemingway', 'Ilka Chase'],
# ...
#  'Edward Samuel Farrow': ['Ernest Hemingway', 'Edward Samuel Farrow'],
#  'Litterio B. Farsaci': ['Ernest Hemingway', 'Litterio B. Farsaci'],
#  'Negley Farson': ['Ernest Hemingway', 'Negley Farson'],
#  'Howard Fast': ['Ernest Hemingway', 'Howard Fast'],
#  'Anton Pavlovich Chekhov': ['Ernest Hemingway', 'Anton Pavlovich Chekhov'],
#  'Alfred Hayes': ['Ernest Hemingway', 'Alfred Hayes'],
#  'Carlton Joseph Huntley Hayes': ['Ernest Hemingway',
#   'Carlton Joseph Huntley Hayes'],
#  'Nelson Hayes': ['Ernest Hemingway', 'Nelson Hayes'],
#  'Elinor Rice': ['Ernest Hemingway', 'Elinor Rice'],
#  'H. R. Hays': ['Ernest Hemingway', 'H. R. Hays'],
#  'Ladd Haystead': ['Ernest Hemingway', 'Ladd Haystead'],
#  'Paul Hazard': ['Ernest Hemingway', 'Paul Hazard'],
#  'William Hazlitt': ['Ernest Hemingway', 'William Hazlitt'],
#  'Gerald Heard': ['Ernest Hemingway', 'Gerald Heard'],
#  'Paul Leonard': ['Ernest Hemingway', 'Paul Leonard'],
#  'John Hearne': ['Ernest Hemingway', 'John Hearne'],
#  'Basil Heatter': ['Ernest Hemingway', 'Basil Heatter'],
#  'W. L. Heath': ['Ernest Hemingway', 'W. L. Heath'],
#  'Eric William Heaton': ['Ernest Hemingway', 'Eric William Heaton'],
#  'Ben Hecht': ['Ernest Hemingway', 'Ben Hecht'],
#  'Sven Anders Hedin': ['Ernest Hemingway', 'Sven Anders Hedin'],
#  'U. P. Hedrick': ['Ernest Hemingway', 'U. P. Hedrick'],
#  'Van Campen Heilner': ['Ernest Hemingway', 'Van Campen Heilner'],
#  'Heinz Helfgen': ['Ernest Hemingway', 'Heinz Helfgen'],
#  'Constance Helmericks': ['Ernest Hemingway', 'Constance Helmericks'],
#  'Alfred Tyler Hemingway': ['Ernest Hemingway', 'Alfred Tyler Hemingway'],
#  'Leicester Hemingway': ['Ernest Hemingway', 'Leicester Hemingway'],
#  'Cecil Hemley': ['Ernest Hemingway', 'Cecil Hemley'],
#  'Alexander Henderson': ['Ernest Hemingway', 'Alexander Henderson'],
#  'J.Y. Henderson': ['Ernest Hemingway', 'J.Y. Henderson'],
#  'Sir Nevile Henderson': ['Ernest Hemingway', 'Sir Nevile Henderson'],
#  'Philip Henderson': ['Ernest Hemingway', 'Philip Henderson'],
#  'Andy Hennig': ['Ernest Hemingway', 'Andy Hennig'],
#  'Florette Henri': ['Ernest Hemingway', 'Florette Henri'],
#  'Émile Henriot': ['Ernest Hemingway', 'Émile Henriot'],
#  'Robert David Quixano Henriques': ['Ernest Hemingway',
#   'Robert David Quixano Henriques'],
#  'George William Henry': ['Ernest Hemingway', 'George William Henry'],
#  'William Mellors Henry': ['Ernest Hemingway', 'William Mellors Henry'],
#  'Nat Hentoff': ['Ernest Hemingway', 'Nat Hentoff'],
#  'G. A. Henty': ['Ernest Hemingway', 'G. A. Henty'],
#  'Henry William Herbert': ['Ernest Hemingway', 'Henry William Herbert'],
#  'Xavier Herbert': ['Ernest Hemingway', 'Xavier Herbert'],
#  'Josephine Herbst': ['Ernest Hemingway', 'Josephine Herbst'],
#  'Joseph Hergesheimer': ['Ernest Hemingway', 'Joseph Hergesheimer'],
#  'S. Heriz-Smith': ['Ernest Hemingway', 'S. Heriz-Smith'],
#  'Rafael Hernández': ['Ernest Hemingway', 'Rafael Hernández'],
#  'F. Hernández-Girbal': ['Ernest Hemingway', 'F. Hernández-Girbal'],
#  'Giuseppe Fattorusso': ['Ernest Hemingway', 'Giuseppe Fattorusso'],
#  'Henri Fauconnier': ['Ernest Hemingway', 'Henri Fauconnier'],
#  'William Faulkner': ['Ernest Hemingway', 'William Faulkner'],
#  'Frederick [Evan Evans] Faust': ['Ernest Hemingway',
#   'Frederick [Evan Evans] Faust'],
#  'Frederick [Max Brand] Faust': ['Ernest Hemingway',
#   'Frederick [Max Brand] Faust'],
#  'William Henry Herndon': ['Ernest Hemingway', 'William Henry Herndon'],
#  'John Herrmann': ['Ernest Hemingway', 'John Herrmann'],
#  'Ruth Herschberger': ['Ernest Hemingway', 'Ruth Herschberger'],
#  'John Hersey': ['Ernest Hemingway', 'John Hersey'],
#  'Melville J. Herskovits': ['Ernest Hemingway', 'Melville J. Herskovits'],
#  'Maurice Herzog': ['Ernest Hemingway', 'Maurice Herzog'],
#  'Kurt Heuser': ['Ernest Hemingway', 'Kurt Heuser'],
#  'Theodor Heuss': ['Ernest Hemingway', 'Theodor Heuss'],
#  'Edward R. Hewitt': ['Ernest Hemingway', 'Edward R. Hewitt'],
#  'Edward Ringwood Hewitt': ['Ernest Hemingway', 'Edward Ringwood Hewitt'],
#  'Maurice Henry Hewlett': ['Ernest Hemingway', 'Maurice Henry Hewlett'],
#  'Ronald Hewitt': ['Ernest Hemingway', 'Ronald Hewitt'],
#  'Thor Heyerdahl': ['Ernest Hemingway', 'Thor Heyerdahl'],
#  'John Hosford Hickey': ['Ernest Hemingway', 'John Hosford Hickey'],
#  'Joseph J. Hickey': ['Ernest Hemingway', 'Joseph J. Hickey'],
#  'James E. Hicks': ['Ernest Hemingway', 'James E. Hicks'],
#  'Kurt Hielscher': ['Ernest Hemingway', 'Kurt Hielscher'],
#  'Gilbert Highet': ['Ernest Hemingway', 'Gilbert Highet'],
#  'Hugh Percy Highton': ['Ernest Hemingway', 'Hugh Percy Highton'],
#  'Howard Hill': ['Ernest Hemingway', 'Howard Hill'],
#  'Percy A. Hill': ['Ernest Hemingway', 'Percy A. Hill'],
#  'Russell Hill': ['Ernest Hemingway', 'Russell Hill'],
#  'Weldon Hill': ['Ernest Hemingway', 'Weldon Hill'],
#  'Edmund Hillary': ['Ernest Hemingway', 'Edmund Hillary'],
#  'Edgar C. Hilliard': ['Ernest Hemingway', 'Edgar C. Hilliard'],
#  'James Hilton': ['Ernest Hemingway', 'James Hilton'],
#  'Chester B. Himes': ['Ernest Hemingway', 'Chester B. Himes'],
#  'Harold Percival Himsworth': ['Ernest Hemingway',
#   'Harold Percival Himsworth'],
#  'Maurice Gerschon Hindus': ['Ernest Hemingway', 'Maurice Gerschon Hindus'],
#  'Duncan Hines': ['Ernest Hemingway', 'Duncan Hines'],
#  'Hans Hinrichs': ['Ernest Hemingway', 'Hans Hinrichs'],
#  'Eric C. Hiscock': ['Ernest Hemingway', 'Eric C. Hiscock'],
#  'Ernest Haycox': ['Ernest Hemingway', 'Ernest Haycox'],
#  'Adolf Hitler': ['Ernest Hemingway', 'Adolf Hitler'],
#  'John Favill': ['Ernest Hemingway', 'John Favill'],
#  'Percy Harrison Fawcett': ['Ernest Hemingway', 'Percy Harrison Fawcett'],
#  'Kenneth Fearing': ['Ernest Hemingway', 'Kenneth Fearing'],
#  "Federal Writers' Project": ['Ernest Hemingway', "Federal Writers' Project"],
#  'Alexander Fedoroff': ['Ernest Hemingway', 'Alexander Fedoroff'],
#  'Herbert Feis': ['Ernest Hemingway', 'Herbert Feis'],
#  'Rose Caroline Feld': ['Ernest Hemingway', 'Rose Caroline Feld'],
#  'Gene Feldman': ['Ernest Hemingway', 'Gene Feldman'],
#  'Florent Fels': ['Ernest Hemingway', 'Florent Fels'],
#  'Henry G. Felsen': ['Ernest Hemingway', 'Henry G. Felsen'],
#  'Edwin Felsinger': ['Ernest Hemingway', 'Edwin Felsinger'],
#  'Doreen Yen Hung Feng': ['Ernest Hemingway', 'Doreen Yen Hung Feng'],
#  'Carroll Lane Fenton': ['Ernest Hemingway', 'Carroll Lane Fenton'],
#  'Charles A. Fenton': ['Ernest Hemingway', 'Charles A. Fenton'],
#  'Richard Ferber': ['Ernest Hemingway', 'Richard Ferber'],
#  'Robert Ferguson': ['Ernest Hemingway', 'Robert Ferguson'],
#  'Sir Bernard Fergusson': ['Ernest Hemingway', 'Sir Bernard Fergusson'],
#  'Erna Fergusson': ['Ernest Hemingway', 'Erna Fergusson'],
#  'Harvey Fergusson': ['Ernest Hemingway', 'Harvey Fergusson'],
#  'Antonio Fernández Coello de Portugal': ['Ernest Hemingway',
#   'Antonio Fernández Coello de Portugal'],
#  'José Antonio Fernández de Castro': ['Ernest Hemingway',
#   'José Antonio Fernández de Castro'],
#  'Antonio [Hache] Fernández de Heredia': ['Ernest Hemingway',
#   'Antonio [Hache] Fernández de Heredia'],
#  'Ricardo Fernández de la Reguera': ['Ernest Hemingway',
#   'Ricardo Fernández de la Reguera'],
#  'Francisco Fernández Fierros': ['Ernest Hemingway',
#   'Francisco Fernández Fierros'],
#  'Fidel Fernández Martínez': ['Ernest Hemingway', 'Fidel Fernández Martínez'],
#  'Jesús Fernández Santos': ['Ernest Hemingway', 'Jesús Fernández Santos'],
#  'Ramón Ferreira': ['Ernest Hemingway', 'Ramón Ferreira'],
#  'Augusto Ferrer de Couto': ['Ernest Hemingway', 'Augusto Ferrer de Couto'],
#  'Agustina Surama de las Mercedes Ferrer Deulofeu': ['Ernest Hemingway',
#   'Agustina Surama de las Mercedes Ferrer Deulofeu'],
#  'António Ferro': ['Ernest Hemingway', 'António Ferro'],
#  'Nicholas Fersen': ['Ernest Hemingway', 'Nicholas Fersen'],
#  'Lion Feuchtwanger': ['Ernest Hemingway', 'Lion Feuchtwanger'],
#  'George S. Fichter (ed.)': ['Ernest Hemingway', 'George S. Fichter (ed.)'],
#  'Leslie A. Fiedler': ['Ernest Hemingway', 'Leslie A. Fiedler'],
#  'Peter Field': ['Ernest Hemingway', 'Peter Field'],
#  'Wooster Bard Field': ['Ernest Hemingway', 'Wooster Bard Field'],
#  'Editors of Field and Stream (periodical)': ['Ernest Hemingway',
#   'Editors of Field and Stream (periodical)'],
#  'Daphne Fielding': ['Ernest Hemingway', 'Daphne Fielding'],
#  'Henry Fielding': ['Ernest Hemingway', 'Henry Fielding'],
#  'W. Chenevard': ['Ernest Hemingway', 'W. Chenevard'],
#  'Sheldon Cheney': ['Ernest Hemingway', 'Sheldon Cheney'],
#  'Albert Chérel': ['Ernest Hemingway', 'Albert Chérel'],
#  'Xan Fielding': ['Ernest Hemingway', 'Xan Fielding'],
#  'Apsley Cherry-Garrard': ['Ernest Hemingway', 'Apsley Cherry-Garrard'],
#  'René Chesal': ['Ernest Hemingway', 'René Chesal'],
#  'Gifford Paul Cheshire': ['Ernest Hemingway', 'Gifford Paul Cheshire'],
#  'Caryl Chessman': ['Ernest Hemingway', 'Caryl Chessman'],
#  'G. K. Chesterton': ['Ernest Hemingway', 'G. K. Chesterton'],
#  'Kai-shek Chiang': ['Ernest Hemingway', 'Kai-shek Chiang'],
#  'Mei-ling Sung Chiang': ['Ernest Hemingway', 'Mei-ling Sung Chiang'],
#  'Erskine Childers': ['Ernest Hemingway', 'Erskine Childers'],
#  'Herbert Childs': ['Ernest Hemingway', 'Herbert Childs'],
#  'Marquis W. Childs': ['Ernest Hemingway', 'Marquis W. Childs'],
#  'Jashwant Rao Chitambar': ['Ernest Hemingway', 'Jashwant Rao Chitambar'],
#  'Agatha Christie': ['Ernest Hemingway', 'Agatha Christie'],
#  'Christina [pseud.]': ['Ernest Hemingway', 'Christina [pseud.]'],
#  'Winston Churchill': ['Ernest Hemingway', 'Winston Churchill'],
#  'Winston Leonard Spencer Churchill': ['Ernest Hemingway',
#   'Winston Leonard Spencer Churchill'],
#  'Sir Winston Churchill': ['Ernest Hemingway', 'Sir Winston Churchill'],
#  'Marchette Gaylord Chute': ['Ernest Hemingway', 'Marchette Gaylord Chute'],
#  'El Cid Campeador': ['Ernest Hemingway', 'El Cid Campeador'],
#  'Higinio Ciria y Nasarre': ['Ernest Hemingway', 'Higinio Ciria y Nasarre'],
#  'Alejandro Cirici Pellicer': ['Ernest Hemingway',
#   'Alejandro Cirici Pellicer'],
#  'Bert Claflin': ['Ernest Hemingway', 'Bert Claflin'],
#  'Jules Claretie': ['Ernest Hemingway', 'Jules Claretie'],
#  'Barrett H. Clark': ['Ernest Hemingway', 'Barrett H. Clark'],
#  'Paul Fierens': ['Ernest Hemingway', 'Paul Fierens'],
#  'Giovanni da [called Fra Angelico] Fiesole': ['Ernest Hemingway',
#   'Giovanni da [called Fra Angelico] Fiesole'],
#  'Louis Figuier': ['Ernest Hemingway', 'Louis Figuier'],
#  'Percy Finch': ['Ernest Hemingway', 'Percy Finch'],
#  'Jack Finney': ['Ernest Hemingway', 'Jack Finney'],
#  'C.A. Finsterbusch': ['Ernest Hemingway', 'C.A. Finsterbusch'],
#  'Giuseppe Fiocco': ['Ernest Hemingway', 'Giuseppe Fiocco'],
#  'Delbert Clark': ['Ernest Hemingway', 'Delbert Clark'],
#  'James Anthony Clark': ['Ernest Hemingway', 'James Anthony Clark'],
#  'Margaret Fishback': ['Ernest Hemingway', 'Margaret Fishback'],
#  'John Bigelow Clark': ['Ernest Hemingway', 'John Bigelow Clark'],
#  'Morris Fishbein': ['Ernest Hemingway', 'Morris Fishbein'],
#  'Leonard Francis Clark': ['Ernest Hemingway', 'Leonard Francis Clark'],
#  'Marguerite Clark': ['Ernest Hemingway', 'Marguerite Clark'],
#  'Charles Fisher': ['Ernest Hemingway', 'Charles Fisher'],
#  'Mark W. Clark': ['Ernest Hemingway', 'Mark W. Clark'],
#  'Jacob Fisher': ['Ernest Hemingway', 'Jacob Fisher'],
#  'Sydney Clark': ['Ernest Hemingway', 'Sydney Clark'],
#  'James Fisher': ['Ernest Hemingway', 'James Fisher'],
#  'Mary Frances Kennedy Fisher': ['Ernest Hemingway',
#   'Mary Frances Kennedy Fisher'],
#  'Vardis Fisher': ['Ernest Hemingway', 'Vardis Fisher'],
#  'John Fitch': ['Ernest Hemingway', 'John Fitch'],
#  'Dudley Fitts': ['Ernest Hemingway', 'Dudley Fitts'],
#  'Grancel Fitz': ['Ernest Hemingway', 'Grancel Fitz'],
#  'F. Scott Fitzgerald': ['Ernest Hemingway', 'F. Scott Fitzgerald'],
#  'James Percy Fitzpatrick': ['Ernest Hemingway', 'James Percy Fitzpatrick'],
#  'Ennio Flaiano': ['Ernest Hemingway', 'Ennio Flaiano'],
#  'Charles Macomb Flandrau': ['Ernest Hemingway', 'Charles Macomb Flandrau'],
#  'Janet Flanner': ['Ernest Hemingway', 'Janet Flanner'],
#  'Gustave Flaubert': ['Ernest Hemingway', 'Gustave Flaubert'],
#  'Martin Flavin': ['Ernest Hemingway', 'Martin Flavin'],
#  'Nathaniel S. Fleischer': ['Ernest Hemingway', 'Nathaniel S. Fleischer'],
#  'Hector Fleischmann': ['Ernest Hemingway', 'Hector Fleischmann'],
#  'Ian Fleming': ['Ernest Hemingway', 'Ian Fleming'],
#  'Peter Fleming': ['Ernest Hemingway', 'Peter Fleming'],
#  'Walter Van Tilburg Clark': ['Ernest Hemingway', 'Walter Van Tilburg Clark'],
#  'Arthur Charles Clarke': ['Ernest Hemingway', 'Arthur Charles Clarke'],
#  'Jerry Clason': ['Ernest Hemingway', 'Jerry Clason'],
#  'Karl von Clausewitz': ['Ernest Hemingway', 'Karl von Clausewitz'],
#  'Maximiliano Clavo': ['Ernest Hemingway', 'Maximiliano Clavo'],
#  'Jon Cleary': ['Ernest Hemingway', 'Jon Cleary'],
#  'Irene Cleaton': ['Ernest Hemingway', 'Irene Cleaton'],
#  'Agnes Morley Cleaveland': ['Ernest Hemingway', 'Agnes Morley Cleaveland'],
#  'Georges Eugène Benjamin Clemenceau': ['Ernest Hemingway',
#   'Georges Eugène Benjamin Clemenceau'],
#  'Samuel Langhorne Clemens': ['Ernest Hemingway', 'Samuel Langhorne Clemens'],
#  'Walter Clemons': ['Ernest Hemingway', 'Walter Clemons'],
#  'Logan Clendening': ['Ernest Hemingway', 'Logan Clendening'],
#  'Hugh Clevely': ['Ernest Hemingway', 'Hugh Clevely'],
#  'Natalie Clifford Barney': ['Ernest Hemingway', 'Natalie Clifford Barney'],
#  'Sir Henry Clifford': ['Ernest Hemingway', 'Sir Henry Clifford'],
#  'Charmian Clift': ['Ernest Hemingway', 'Charmian Clift'],
#  'Daniel Joseph Clinton': ['Ernest Hemingway', 'Daniel Joseph Clinton'],
#  'Stuart Cloete': ['Ernest Hemingway', 'Stuart Cloete'],
#  'Pierre Clostermann': ['Ernest Hemingway', 'Pierre Clostermann'],
#  'Club des Auberges de France': ['Ernest Hemingway',
#   'Club des Auberges de France'],
#  'Woodworth Clum': ['Ernest Hemingway', 'Woodworth Clum'],
#  'Henry Troth Coates': ['Ernest Hemingway', 'Henry Troth Coates'],
#  'John Coates': ['Ernest Hemingway', 'John Coates'],
#  'Robert Myron Coates': ['Ernest Hemingway', 'Robert Myron Coates'],
#  'Robert M. Coates': ['Ernest Hemingway', 'Robert M. Coates'],
#  'Henri Cochet': ['Ernest Hemingway', 'Henri Cochet'],
#  'Claud Cockburn': ['Ernest Hemingway', 'Claud Cockburn'],
#  'Jean Cocteau': ['Ernest Hemingway', 'Jean Cocteau'],
#  'Charles R. Codman': ['Ernest Hemingway', 'Charles R. Codman'],
#  'Harold Flender': ['Ernest Hemingway', 'Harold Flender'],
#  'Barthold Fles (ed.)': ['Ernest Hemingway', 'Barthold Fles (ed.)'],
#  'Frank Irving Fletcher': ['Ernest Hemingway', 'Frank Irving Fletcher'],
#  'James Thomas Flexner': ['Ernest Hemingway', 'James Thomas Flexner'],
#  'Grover Flint': ['Ernest Hemingway', 'Grover Flint'],
#  'Charles Bracelen Flood': ['Ernest Hemingway', 'Charles Bracelen Flood'],
#  'Jean Pierre Claris de Florian': ['Ernest Hemingway',
#   'Jean Pierre Claris de Florian'],
#  "Vernon L. [Jim O'Mara] Fluharty": ['Ernest Hemingway',
#   "Vernon L. [Jim O'Mara] Fluharty"],
#  'John Thomas Flynn': ['Ernest Hemingway', 'John Thomas Flynn'],
#  'Ferdinand Foch': ['Ernest Hemingway', 'Ferdinand Foch'],
#  'Marcel William Fodor': ['Ernest Hemingway', 'Marcel William Fodor'],
#  'Hermann Foertsch': ['Ernest Hemingway', 'Hermann Foertsch'],
#  'Martha Foley (ed.)': ['Ernest Hemingway', 'Martha Foley (ed.)'],
#  'Martha Foley': ['Ernest Hemingway', 'Martha Foley'],
#  'Michael [Cassius] Foot': ['Ernest Hemingway', 'Michael [Cassius] Foot'],
#  'Michael Foot': ['Ernest Hemingway', 'Michael Foot'],
#  'John Taintor Foote': ['Ernest Hemingway', 'John Taintor Foote'],
#  'Hulbert Footner': ['Ernest Hemingway', 'Hulbert Footner'],
#  'Gordon Forbes': ['Ernest Hemingway', 'Gordon Forbes'],
#  'Corey Ford': ['Ernest Hemingway', 'Corey Ford'],
#  'George Sturgis Coffin': ['Ernest Hemingway', 'George Sturgis Coffin'],
#  'Howard Macy Coffin': ['Ernest Hemingway', 'Howard Macy Coffin'],
#  'Tristram Coffin': ['Ernest Hemingway', 'Tristram Coffin'],
#  'Joseph Cohen': ['Ernest Hemingway', 'Joseph Cohen'],
#  'Art Cohn': ['Ernest Hemingway', 'Art Cohn'],
#  'Ford Madox Ford': ['Ernest Hemingway', 'Ford Madox Ford'],
#  'David L. Cohn': ['Ernest Hemingway', 'David L. Cohn'],
#  'David Lewis Cohn': ['Ernest Hemingway', 'David Lewis Cohn'],
#  'Louis Henry Cohn': ['Ernest Hemingway', 'Louis Henry Cohn'],
#  ...}

# %%
from networkx.algorithms import approximation
nx.max_clique(libs)

# %%
print(len(libs.nodes('Ernest Hemingway')))
print(len(libs.nodes('Langston Hughes')))
print(len(libs.nodes('Louis Henry Cohn')))
# Out:
# 12734
# 12734
# 12734

# %% [markdown]
# **Using Vistorian.net**
#
# I'll create dataframes organized into decades between 1870 and 1969, inclusive (this is the period in which most of the Modernist Libraries' books were published).  If a book's publication date is unknown or invalid, I'll exclude it from the dataframe (roughly 10% of the books in the Modernist Libraries dataset).  If a book has a range of publication dates, I'll simply use the "StartDate" value for the "Year" column for ease of graphing in a network visualization.

# %%
# Create a dataframe of owners, and the authors and publication dates of their books
years1870 = []      # years are edge attributes
years1880 = []      # (if an owner has multiple books by one author, they'll have multiple edges between them)
years1890 = []
years1900 = []
years1910 = []
years1920 = []
years1930 = []
years1940 = []
years1950 = []
years1950B = []
years1960 = []
targets1870 = []     # target nodes are authors
targets1880 = []
targets1890 = []
targets1900 = []
targets1910 = []
targets1920 = []
targets1930 = []
targets1940 = []
targets1950 = []
targets1950B = []
targets1960 = []
sources1870 = []     # sources nodes are owners
sources1880 = []
sources1890 = []
sources1900 = []
sources1910 = []
sources1920 = []
sources1930 = []
sources1940 = []
sources1950 = []
sources1950B = []
sources1960 = []
for key in owners:
    yr = StartYear[key]
    if (yr != 9999) and (len(str(yr)) == 4):
        if (yr > 1869) and (yr < 1880):
            sources1870 += [owners[key]]
            years1870 += [int(yr)]
            targets1870 += [authors[key]]
        if (yr > 1879) and (yr < 1890):
            sources1880 += [owners[key]]
            years1880 += [int(yr)]
            targets1880 += [authors[key]]
        if (yr > 1889) and (yr < 1900):
            sources1890 += [owners[key]]
            years1890 += [int(yr)]
            targets1890 += [authors[key]]
        if (yr > 1899) and (yr < 1910):
            sources1900 += [owners[key]]
            years1900 += [int(yr)]
            targets1900 += [authors[key]]
        if (yr > 1909) and (yr < 1920):
            sources1910 += [owners[key]]
            years1910 += [int(yr)]
            targets1910 += [authors[key]]
        if (yr > 1919) and (yr < 1930):
            sources1920 += [owners[key]]
            years1920 += [int(yr)]
            targets1920 += [authors[key]]
        if (yr > 1929) and (yr < 1940):
            sources1930 += [owners[key]]
            years1930 += [int(yr)]
            targets1930 += [authors[key]]
        if (yr > 1939) and (yr < 1950):
            sources1940 += [owners[key]]
            years1940 += [int(yr)]
            targets1940 += [authors[key]]
        if (yr > 1949) and (yr < 1955):
            sources1950 += [owners[key]]
            years1950 += [int(yr)]
            targets1950 += [authors[key]]
        if (yr > 1954) and (yr < 1960):
            sources1950B += [owners[key]]
            years1950B += [int(yr)]
            targets1950B += [authors[key]]
        if (yr > 1959) and (yr < 1970):
            sources1960 += [owners[key]]
            years1960 += [int(yr)]
            targets1960 += [authors[key]]

print("1870s:", len(years1870))
print("1880s:", len(years1880))
print("1890s:", len(years1890))
print("1900s:", len(years1900))
print("1910s:", len(years1910))
print("1920s:", len(years1920))
print("1930s:", len(years1930))
print("1940s:", len(years1940))
print("1950-54:", len(years1950))
print("1955-59:", len(years1950B))
print("1960s:", len(years1960))

df1870s = pd.DataFrame( { 'Book Owner' : sources1870, 'Book Author' : targets1870, 'Publication Year' : years1870 })
df1880s = pd.DataFrame( { 'Book Owner' : sources1880, 'Book Author' : targets1880, 'Publication Year' : years1880 })
df1890s = pd.DataFrame( { 'Book Owner' : sources1890, 'Book Author' : targets1890, 'Publication Year' : years1890 })
df1900s = pd.DataFrame( { 'Book Owner' : sources1900, 'Book Author' : targets1900, 'Publication Year' : years1900 })
df1910s = pd.DataFrame( { 'Book Owner' : sources1910, 'Book Author' : targets1910, 'Publication Year' : years1910 })
df1920s = pd.DataFrame( { 'Book Owner' : sources1920, 'Book Author' : targets1920, 'Publication Year' : years1920 })
df1930s = pd.DataFrame( { 'Book Owner' : sources1930, 'Book Author' : targets1930, 'Publication Year' : years1930 })
df1940s = pd.DataFrame( { 'Book Owner' : sources1940, 'Book Author' : targets1940, 'Publication Year' : years1940 })
df1950sA = pd.DataFrame( { 'Book Owner' : sources1950, 'Book Author' : targets1950, 'Publication Year' : years1950 })
df1950sB = pd.DataFrame( { 'Book Owner' : sources1950B, 'Book Author' : targets1950B, 'Publication Year' : years1950B })
df1960s = pd.DataFrame( { 'Book Owner' : sources1960, 'Book Author' : targets1960, 'Publication Year' : years1960 })

# Export the dataframes as CSV files to create link tables to visualize in vistorian.net
#df1870s.to_csv('owners_authors_1870.csv')
#df1880s.to_csv('owners_authors_1880.csv')
#df1890s.to_csv('owners_authors_1890.csv')
#df1900s.to_csv('owners_authors_1900.csv')
#df1910s.to_csv('owners_authors_1910.csv')
#df1920s.to_csv('owners_authors_1920.csv')
#df1930s.to_csv('owners_authors_1930.csv')
#df1940s.to_csv('owners_authors_1940.csv')
df1950sA.to_csv('owners_authors_1950A.csv')
df1950sB.to_csv('owners_authors_1950B.csv')
#df1960s.to_csv('owners_authors_1960.csv')
# Out:
# 1870s: 302
# 1880s: 491
# 1890s: 1017
# 1900s: 1402
# 1910s: 1633
# 1920s: 3160
# 1930s: 3350
# 1940s: 3235
# 1950-54: 1778
# 1955-59: 2128
# 1960s: 1436

# %% [markdown]
# For explanatory purposes in DS4D Assignment 3, we'll be focusing on four people in the Modernist Libraries dataset to tell a story about what literary researchers can get out of the dataset:
#
# * Ernest Hemingway
# * Gertrude Stein
# * Ezra Pound
# * Georges Simenon
#
# One Vistorian network visualization will contain every book these four people owned as recorded in the dataset, and another will contain owners of books written by one of these four people.

# %%
# Make network nodes for the four people above, accounting for their presence in the dataset as author or owner
vis1AuthList = []
vis1OwnList = []
vis1DateList = []
vis1TitleList = []

vis1AuthList1800 = []
vis1AuthList1850 = []
vis1AuthList1900 = []
vis1AuthList1925 = []
vis1AuthList1950 = []

vis1OwnList1800 = []
vis1OwnList1850 = []
vis1OwnList1900 = []
vis1OwnList1925 = []
vis1OwnList1950 = []

vis1DateList1800 = []
vis1DateList1850 = []
vis1DateList1900 = []
vis1DateList1925 = []
vis1DateList1950 = []

vis1TitleList1800 = []
vis1TitleList1850 = []
vis1TitleList1900 = []
vis1TitleList1925 = []
vis1TitleList1950 = []

vis2AuthList = []
vis2OwnList = []
vis2DateList = []
vis2TitleList = []

total = len(owners)

for i in range(0, total):
    # ensure owners names are all lowercase to account for any capitalization inconsistencies that may be in the dataset
    o = (str(owners[i])).lower()
    a = (str(authors[i])).lower()
    y = StartYear[i]
    if (y != 9999) and (y > 1800):
        # Books of one another's the four authors owned
        if ("ernest hemingway" in o) or ("gertrude stein" in o) or ("ezra pound" in o) or ("georges simenon" in o):
            if ("ernest hemingway" in a) or ("gertrude stein" in a) or ("ezra pound" in a) or ("georges simenon" in a):
                vis1OwnList += [owners[i]]
                vis1AuthList += [authors[i]]
                vis1DateList += [StartYear[i]]  # rely on the earliest publication date provided if range given in dataset
                vis1TitleList += [titles[i]]
                if (y > 1799) and (y < 1850):
                    vis1OwnList1800 += [owners[i]]
                    vis1AuthList1800 += [authors[i]]
                    vis1DateList1800 += [StartYear[i]]  # rely on the earliest publication date provided if range given in dataset
                    vis1TitleList1800 += [titles[i]]
                if (y > 1849) and (y < 1900):
                    vis1OwnList1850 += [owners[i]]
                    vis1AuthList1850 += [authors[i]]
                    vis1DateList1850 += [StartYear[i]]  
                    vis1TitleList1850 += [titles[i]]
                if (y > 1899) and (y < 1925):
                    vis1OwnList1900 += [owners[i]]
                    vis1AuthList1900 += [authors[i]]
                    vis1DateList1900 += [StartYear[i]]  
                    vis1TitleList1900 += [titles[i]]
                if (y > 1924) and (y < 1950):
                    vis1OwnList1925 += [owners[i]]
                    vis1AuthList1925 += [authors[i]]
                    vis1DateList1925 += [StartYear[i]]  
                    vis1TitleList1925 += [titles[i]]
                if (y > 1949) and (y < 1970):
                    vis1OwnList1950 += [owners[i]]
                    vis1AuthList1950 += [authors[i]]
                    vis1DateList1950 += [StartYear[i]]  
                    vis1TitleList1950 += [titles[i]]

        # All books that one of the four authors wrote
        if ("ernest hemingway" in a) or ("gertrude stein" in a) or ("ezra pound" in a) or ("georges simenon" in a):
            vis2OwnList += [owners[i]]
            vis2AuthList += [authors[i]]
            vis2DateList += [StartYear[i]]  # rely on the earliest publication date provided if range given in dataset
            vis2TitleList += [titles[i]]


assert len(vis1OwnList1800) == len(vis1AuthList1800), "Owner and author lists should be the same length"
assert len(vis1DateList1900) == len(vis1AuthList1900), "Date and author lists should be the same length"
assert len(vis1TitleList1950) == len(vis1OwnList1950), "Title and owner lists should be the same length"
assert len(vis2OwnList) == len(vis2AuthList), "Owner and author lists should be the same length"
assert len(vis2DateList) == len(vis2AuthList), "Date and author lists should be the same length"
assert len(vis2TitleList) == len(vis2OwnList), "Title and owner lists should be the same length"

print(len(vis1OwnList1900))
print(len(vis1DateList1925))
print(len(vis1AuthList1950))
print(len(vis1TitleList))
# Out:
# 22
# 103
# 50
# 177

# %%
# Create a dataframe for the four owners listed in the previous cell
A3_owners0 = pd.DataFrame( { 'Book Owner' : vis1OwnList, 'Book Author' : vis1AuthList, 'Publication Year' : vis1DateList, 'Book Title' : vis1TitleList})
#A3_owners1 = pd.DataFrame( { 'Book Owner' : vis1OwnList1800, 'Book Author' : vis1AuthList1800, 'Publication Year' : vis1DateList1800, 'Book Title' : vis1TitleList1800})
#A3_owners2 = pd.DataFrame( { 'Book Owner' : vis1OwnList1850, 'Book Author' : vis1AuthList1850, 'Publication Year' : vis1DateList1850, 'Book Title' : vis1TitleList1850})
#A3_owners3 = pd.DataFrame( { 'Book Owner' : vis1OwnList1900, 'Book Author' : vis1AuthList1900, 'Publication Year' : vis1DateList1900, 'Book Title' : vis1TitleList1900})
#A3_owners4 = pd.DataFrame( { 'Book Owner' : vis1OwnList1925, 'Book Author' : vis1AuthList1925, 'Publication Year' : vis1DateList1925, 'Book Title' : vis1TitleList1925})
#A3_owners5 = pd.DataFrame( { 'Book Owner' : vis1OwnList1950, 'Book Author' : vis1AuthList1950, 'Publication Year' : vis1DateList1950, 'Book Title' : vis1TitleList1950})
A3_owners0.head()
# Out:
#         Book Author        Book Owner  \
# 0  Ernest Hemingway  Ernest Hemingway
# 1  Ernest Hemingway  Ernest Hemingway
# 2  Ernest Hemingway  Ernest Hemingway
# 3  Ernest Hemingway  Ernest Hemingway
# 4  Ernest Hemingway  Ernest Hemingway
#
#                                           Book Title  Publication Year
# 0                             Hemingway par lui-même              1959
# 1       Men at war; the best war stories of all time              1955
# 2       Men at war; the best war stories of all time              1942
# 3      Men at war : the best war stories of all time              1952
# 4  Le vieil homme et la mer: Transcription dramat...              1955

# %%
A3_authors = pd.DataFrame( { 'Book Owner' : vis2OwnList, 'Book Author' : vis2AuthList, 'Publication Year' : vis2DateList, 'Book Title' : vis2TitleList})
A3_authors.tail()
# Out:
#          Book Author               Book Owner  \
# 288   Gertrude Stein           Gertrude Stein
# 289  Gertrude Stein             Edith Sitwell
# 290   Gertrude Stein           Gertrude Stein
# 291   Gertrude Stein           Gertrude Stein
# 292  Georges Simenon  Edna St. Vincent Millay
#
#                                             Book Title  Publication Year
# 288      The Gertrude Stein first reader & three plays              1946
# 289  A book concluding with As a wife has a cow, a ...              1926
# 290  Before the Flowers of Friendship Faded Friends...              1931
# 291                      Autobiografia di Alice Toklas              1938
# 292               The Man Who Watched the Trains Go By              1928

# %%
# Export the dataframes as CSV files to create link tables to visualize in vistorian.net
A3_owners0.to_csv('A3_owners.csv')
#A3_owners1.to_csv('A3_owners_1800-1849.csv')
#A3_owners2.to_csv('A3_owners_1850-1899.csv')
#A3_owners3.to_csv('A3_owners_1900-1924.csv')
#A3_owners4.to_csv('A3_owners_1925-1949.csv')
#A3_owners5.to_csv('A3_owners_1950-1970.csv')
#A3_authors.to_csv('A3_authors.csv')

# %%
# Books both EH and G Stein owned
Hem_Stein_o = []
Hem_Stein_a = []
Hem_Stein_y = []
Hem_Stein_t = []
for i in range(0, total):
    # ensure owners names are all lowercase to account for any capitalization inconsistencies
    o = (str(owners[i])).lower()
    a = (str(authors[i])).lower()
    y = StartYear[i]                 # rely on the earliest publication date provided if range given in dataset
    if (y != 9999) and (y > 1920) and (y < 1940):         #and (y > 1800) and (y < 1970):
        if ("ernest hemingway" in o) or ("gertrude stein" in o):
            Hem_Stein_o += [o]
            Hem_Stein_a += [a]
            Hem_Stein_y += [y]  
            Hem_Stein_t += [titles[i]]

# Books both EH and G Simenon owned
Hem_Sim_o = []
Hem_Sim_a = []
Hem_Sim_y = []
Hem_Sim_t = []
for i in range(0, total):
    # ensure owners names are all lowercase to account for any capitalization inconsistencies
    o = (str(owners[i])).lower()
    a = (str(authors[i])).lower()
    y = StartYear[i]
    if (y != 9999) and (y > 1920) and (y < 1940):         #and (y > 1800) and (y < 1970):
        if ("ernest hemingway" in o) or ("georges simenon" in o):
            Hem_Sim_o += [o]
            Hem_Sim_a += [a]
            Hem_Sim_y += [y] 
            Hem_Sim_t += [titles[i]]

# Books both EH and EP owned
Hem_P_o = []
Hem_P_a = []
Hem_P_y = []
Hem_P_t = []
for i in range(0, total):
    # ensure owners names are all lowercase to account for any capitalization inconsistencies
    o = (str(owners[i])).lower()
    a = (str(authors[i])).lower()
    y = StartYear[i]
    if (y != 9999) and (y > 1920) and (y < 1940):         #and (y > 1800) and (y < 1970):
        if ("ernest hemingway" in o) or ("ezra pound" in o):
            Hem_P_o += [o]
            Hem_P_a += [a]
            Hem_P_y += [y] 
            Hem_P_t += [titles[i]]
print(len(Hem_Stein_o))
print(len(Hem_Sim_a))
print(len(Hem_P_y))
# Out:
# 1758
# 1535
# 1774

# %%
# Create shared ownership dataframes
EH_GStein_1920_40 = pd.DataFrame( { 'Book Owner' : Hem_Stein_o, 'Book Author' : Hem_Stein_a, 'Publication Year' : Hem_Stein_y, 'Book Title' : Hem_Stein_t})
EH_GSim_1920_40 = pd.DataFrame( { 'Book Owner' : Hem_Sim_o, 'Book Author' : Hem_Sim_a, 'Publication Year' : Hem_Sim_y, 'Book Title' : Hem_Sim_t})
EH_EP_1920_40 = pd.DataFrame( { 'Book Owner' : Hem_P_o, 'Book Author' : Hem_P_a, 'Publication Year' : Hem_P_y, 'Book Title' : Hem_P_t})

# Export shared ownership dataframes as CSV files to create link tables to visualize in vistorian.net
#EH_GStein.to_csv('shared_EH_GStein.csv')
#EH_GSim.to_csv('shared_EH_GSim.csv')
#EH_EP.to_csv('shared_EH_EP.csv')

EH_GStein_1920_40.to_csv('shared_EH_GStein_1920-40.csv')
EH_GSim_1920_40.to_csv('shared_EH_GSim_1920-40.csv')
EH_EP_1920_40.to_csv('shared_EH_EP_1920-40.csv')

# %%
print(A3_owners1.shape)
print(A3_owners2.shape)
print(A3_owners3.shape)
print(A3_authors.shape)
# Out:
# (63, 4)
# (459, 4)
# (2891, 4)
# (293, 4)

# %%
GS = []
for key in authors:
    o = (authors[key]).lower()
    if ("georges" in o) or ("simenon" in o):
        GS += [key]
print(len(GS))
# Out:
# 113

# %%
GStein = []
for key in authors:
    a = (authors[key]).lower()
    if ("gertrude stein" in a):
        GStein += [key]
for key in owners:
    o = (owners[key]).lower()
    if ("gertrude stein" in o):
        GStein += [key]
print(len(GStein))
# Out:
# 990

# %%
EH = []
for key in authors:
    a = (authors[key]).lower()
    if ("hemingway" in a):
        EH += [key]
for key in owners:
    o = (owners[key]).lower()
    if ("hemingway" in o):
        EH += [key]
print(len(EH))
# Out:
# 7445

# %%
EP = []
for key in authors:
    a = (authors[key]).lower()
    if ("e" in a) and ("pound" in a):
        EP += [key]
for key in owners:
    o = (owners[key]).lower()
    if ("e" in o) and ("pound" in o):
        EP += [key]
print(len(EP))
# Out:
# 891

# %%
pub1940s = []
for d in StartYear:
    if (d < 1950) and (d > 1939):
        pub1940s += [d]
print(len(pub1940s))
# Out:
# 3235

# %%
pub = []
for d in vis1DateList1900:
    if (d < 1950) and (d > 1939):
        pub += []

# %%
print(len(pub))
# Out:
# 0

# %%
pub2 = []
for d in vis2DateList:
    if (d < 1950) and (d > 1939):
        pub2 += []
print(len(pub2))
# Out:
# 0

# %% [markdown]
# Determine how many books were common across the following pairs of libraries:
# * Ernest Hemingway and Ezra Pound
# * Ernest Hemingway and Gertrude Stein
#
# Determine how many books written by one another that the following people owned in their libraries:
# * Ernest Hemingway and Ezra Pound
# * Ernest Hemingway and Gertrude Stein
# * Ernest Hemingway and Georges Simenon

# %%
# Make network nodes for the four people above, accounting for their presence in the dataset as author or owner
vis1AuthList1800 = []
vis1AuthList1850 = []
vis1AuthList1900 = []
vis1OwnList1800 = []
vis1OwnList1850 = []
vis1OwnList1900 = []
vis1DateList1800 = []
vis1DateList1850 = []
vis1DateList1900 = []
vis1TitleList1800 = []
vis1TitleList1850 = []
vis1TitleList1900 = []
vis2AuthList = []
vis2OwnList = []
vis2DateList = []
vis2TitleList = []
total = len(owners)
for i in range(0, total):
    # ensure owners names are all lowercase to account for any capitalization inconsistencies that may be in the dataset
    o = (str(owners[i])).lower()
    y = StartYear[i]
    if (y != 9999) and (y > 1800):
        if ("ernest hemingway" in o) or ("gertrude stein" in o) or ("ezra pound" in o) or ("georges simenon" in o):
            if (y > 1799) and (y < 1850):
                vis1OwnList1800 += [owners[i]]
                vis1AuthList1800 += [authors[i]]
                vis1DateList1800 += [StartYear[i]]  # rely on the earliest publication date provided if range given in dataset
                vis1TitleList1800 += [titles[i]]
            if (y > 1849) and (y < 1900):
                vis1OwnList1850 += [owners[i]]
                vis1AuthList1850 += [authors[i]]
                vis1DateList1850 += [StartYear[i]]  
                vis1TitleList1850 += [titles[i]]
            if (y > 1899) and (y < 1942):           
                vis1OwnList1900 += [owners[i]]
                vis1AuthList1900 += [authors[i]]
                vis1DateList1900 += [StartYear[i]]  
                vis1TitleList1900 += [titles[i]]



        a = (str(authors[i])).lower()
        if ("ernest hemingway" in a) or ("gertrude stein" in a) or ("ezra pound" in a) or ("georges simenon" in a):
            vis2OwnList += [owners[i]]
            vis2AuthList += [authors[i]]
            vis2DateList += [StartYear[i]]  # rely on the earliest publication date provided if range given in dataset
            vis2TitleList += [titles[i]]


assert len(vis1OwnList) == len(vis1AuthList), "Owner and author lists should be the same length"
#assert len(vis1DateList) == len(vis1AuthList), "Date and author lists should be the same length"
assert len(vis1TitleList) == len(vis1OwnList), "Title and owner lists should be the same length"
assert len(vis2OwnList) == len(vis2AuthList), "Owner and author lists should be the same length"
assert len(vis2DateList) == len(vis2AuthList), "Date and author lists should be the same length"
assert len(vis2TitleList) == len(vis2OwnList), "Title and owner lists should be the same length"
